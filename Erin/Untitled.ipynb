# %%
import indicoio
indicoio.config.api_key  = "b4512f0b7e37fbf0c4b9ace04465963d"
from datetime import datetime
import pymongo

conn = 'mongodb://timanderin.info:27017'
client = pymongo.MongoClient(conn)
speechDB = client.speech_db
debateCOL = speechDB.presidential_debates
presidential_speech = speechDB.presidential_speech
import tokenization as token
clean = speechDB.clean

import pandas as pd
import nltk
#df = pd.read_csv('all.csv', index_col = 0)

# %%
obama = " Here are the results of your efforts:  The lowest unemployment rate in over five years.  A rebounding housing market.  A manufacturing sector that’s adding jobs for the first time since the 1990s.  More oil produced at home than we buy from the rest of the world – the first time that’s happened in nearly twenty years.  Our deficits – cut by more than half.  And for the first time in over a decade, business leaders around the world have declared that China is no longer the world’s number one place to invest; America is."
bush = "In the long run, Americans can be confident about our economic growth. But in the short run, we can all see that that growth is slowing. So last week, my administration reached agreement with Speaker Pelosi and Republican Leader Boehner on a robust growth package that includes tax relief for individuals and families and incentives for business investment. The temptation will be to load up the bill. That would delay it or derail it, and neither option is acceptable. This is a good agreement that will keep our economy growing and our people working, and this Congress must pass it as soon as possible."
carter ="At this time in Iran, 50 Americans are still held captive, innocent victims of terrorism and anarchy. Also at this moment, massive Soviet troops are attempting to subjugate the fiercely independent and deeply religious people of Afghanistan. These two acts—one of international terrorism and one of military aggression—present a serious challenge to the United States of America and indeed to all the nations of the world. Together, we will meet these threats to peace."

indicoio.political([obama,bush,carter])
# Out:
# [{'Green': 0.28563336,
#   'Liberal': 0.25907615,
#   'Libertarian': 0.24111158,
#   'Conservative': 0.21417892},
#  {'Libertarian': 0.37462157,
#   'Conservative': 0.32799494,
#   'Liberal': 0.2574681,
#   'Green': 0.039915375},
#  {'Liberal': 0.3515573,
#   'Libertarian': 0.2760506,
#   'Conservative': 0.21875855,
#   'Green': 0.15363353}]

# %%
  indicoio.political("I have a constitutional right to bear arms!")

  # batch example
  indicoio.political([
      "I have a constitutional right to bear arms!",
      "I wish more candidates cared about the environment."
  ])
# Out:
# [{'Libertarian': 0.3674822,
#   'Green': 0.32515982,
#   'Conservative': 0.19319604,
#   'Liberal': 0.11416193},
#  {'Green': 0.8877605,
#   'Libertarian': 0.049544327,
#   'Liberal': 0.03157693,
#   'Conservative': 0.031118236}]

# %%
print(indicoio.political(results[0]['text']))
print(indicoio.sentiment_hq(results[0]['text']))
print(indicoio.personality(results[0]['text']))
print(indicoio.emotion(results[0]['text']))
# Out:
# {'Liberal': 0.72539127, 'Libertarian': 0.108099364, 'Green': 0.09761629, 'Conservative': 0.06889304}
# 0.620108
# {'extraversion': 0.4667181261515213, 'openness': 0.71722925099257, 'agreeableness': 0.4638151536908066, 'conscientiousness': 0.40752386789897393}
# {'fear': 0.32117804884910583, 'joy': 0.28454193472862244, 'anger': 0.24974662065505981, 'sadness': 0.1255236268043518, 'surprise': 0.01900975964963436}

# %% [markdown]
# PYMONGO notes
#
# # Update a document
# db.classroom.update_one(
#     {'name': 'Ahmed'},
#     {'$set':
#         {'row': 4}
#      }
# )
#
# # Add an item to a document array
# db.classroom.update_one(
#     {'name': 'Ahmed'},
#     {'$push':
#         {'hobbies': 'Listening to country music'}
#      }
# )

# %%
print(indicoio.keywords(results[0]['text']),3)

# %%
#print(indicoio.people(results[0]['text']))

thing = indicoio.places(results[0]['text'])
#print(indicoio.organizations(results[0]['text']))
print(type(thing))
print(thing[0]['text'])
# Out:
# <class 'list'>
# New York

# %%
##SAVED CODE

test = debateCOL.find()

for r in range(0,41):
    full_text.replace("\n"," ")
    
    
    political_IND = indicoio.political(test[r]['text'])
    sentiment_IND = indicoio.sentiment_hq(test[r]['text'])
    personality_IND = indicoio.personality(test[r]['text'])
    emotion_IND = indicoio.emotion(test[r]['text'])
    personas_IND = indicoio.personas(test[r]['text'])
    people_IND = []
    places_IND = []
    organizations_IND = []
    
    people = indicoio.people(test[r]['text'])
    places = indicoio.places(test[r]['text'])
    things = indicoio.organizations(test[r]['text'])
    
    for p in range(len(people)):
        people_IND.append(people[p]['text'])
    
    for p in places:
        places_IND.append(places[p]['text'])
   
    for t in things:
        organizations_IND.append(things[t]['text'])
# Out:
# {'executive': 0.019332759082317352, 'entrepreneur': 0.03049737998590935, 'consul': 0.015841120398841436, 'entertainer': 0.02498932772665419, 'commander': 0.06596962512327234, 'debater': 0.10406691829263168, 'protagonist': 0.054055023184668406, 'campaigner': 0.08527166359598921, 'logistician': 0.028996261808602753, 'virtuoso': 0.04574153032988976, 'defender': 0.02375932258829529, 'adventurer': 0.03748027183516843, 'architect': 0.09894461785969197, 'logician': 0.1560848866892798, 'advocate': 0.08107448848480743, 'mediator': 0.12789480238821233}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-7558491b2d4d> in <module>()
#       2 print(indicoio.personas(results[0]['text']))
#       3 indicoio.text_features(results[0]['text'])
# ----> 4 indicoio.relevance(results[0]['text'])
#       5
#       6 indicoio.summarization(results[0]['text'])
#
# ~\Anaconda3\lib\site-packages\indicoio\utils\decorators.py in wrapper(*args, **kwargs)
#      11         if isinstance(args[0], list):
#      12             kwargs['batch'] = True
# ---> 13         return f(*args, **kwargs)
#      14     return wrapper
#
# TypeError: relevance() missing 1 required positional argument: 'queries'

# %%
test = debateCOL.find()
test[41]
# Out:
# {'_id': ObjectId('5d3a9315101b81f283a20eb8'),
#  'year': datetime.datetime(1960, 10, 21, 0, 0),
#  'hash': '0f9bf06a5c62006c54230381c07d211e',
#  'text': '\nOctober 21, 1960\n\nThe Fourth Kennedy-Nixon Presidential Debate\nQUINCY HOWE, MODERATOR: I am Quincy Howe of CB- of ABC News saying good evening from New York where the two major candidates for president of the United States are about to engage in their fourth radio-television discussion of the present campaign. Tonight these men will confine that discussion to foreign policy. Good evening, Vice President Nixon.\nMR. NIXON: Good evening, Mr. Howe.\nMR. HOWE: And good evening, Senator Kennedy.\nMR. KENNEDY: Good evening, Mr. Howe.\nMR. HOWE: Now let me read the rules and conditions under which the candidates themselves have agreed to proceed. As they did in their first meeting, both men will make opening statements of about eight minutes each and closing statements of equal time running three to five minutes each. During the half hour between the opening and closing statements, the candidates will answer and comment upon questions from a panel of four correspondents chosen by the nationwide networks that carry the program. Each candidate will be questioned in turn with opportunity for comment by the other. Each answer will be limited to two and one-half minutes, each comment to one and one-half minutes. The correspondents are free to ask any questions they choose in the field of foreign affairs. Neither candidate knows what questions will be asked. Time alone will determine the final question. Reversing the order in their first meeting, Senator Kennedy will make the second opening statement and the first closing statement. For the first opening statement, here is Vice President Nixon.\nMR. NIXON: Mr. Howe, Senator Kennedy, my fellow Americans. Since this campaign began I have had a very rare privilege. I have traveled to forty-eight of the fifty states and in my travels I have learned what the people of the United States are thinking about. There is one issue that stands out above all the rest, one in which every American is concerned, regardless of what group he may be a member and regardless of where he may live. And that issue, very simply stated, is this: how can we keep the peace – keep it without surrender? How can we extend freedom – extend it without war? Now in determining how we deal with this issue, we must find the answer to a very important but simple question: who threatens the peace? Who threatens freedom in the world? There is only one threat to peace and one threat to freedom – that that is presented by the international Communist movement. And therefore if we are to have peace, we must know how to deal with the Communists and their leaders. I know Mr. Khrushchev. I also have had the opportunity of knowing and meeting other Communist leaders in the world. I believe there are certain principles we must find in dealing with him and his colleagues – principles, if followed, that will keep the peace and that also can extend freedom. First, we have to learn from the past, because we cannot afford to make the mistakes of the past. In the seven years before this Administration came into power in Washington, we found that six hundred million people went behind the Iron Curtain. And at the end of that seven years we were engaged in a war in Korea which cost of thirty thousand American lives. In the past seven years, in President Eisenhower’s Administration, this situation has been reversed. We ended the Korean War; by strong, firm leadership we have kept out of other wars; and we have avoided surrender of principle or territory at the conference table. Now why were we successful, as our predecessors were not successful? I think there’re several reasons. In the first place, they made a fatal error in misjudging the Communists; in trying to apply to them the same rules of conduct that you would apply to the leaders of the free world. One of the major errors they made was the one that led to the Korean War. In ruling out the defense of Korea, they invited aggression in that area. They thought they were going t ...
#  'tag': 'debate'}

# %%
test = debateCOL.find()

for r in range(0,41):
    id = test[r]['_id']
    
    text = test[r]['text']
    
    
    #basic cleanup
    text = text.replace("\n"," ")
    text = text.replace("\s+"," ")
    
    #pulling measurements/features from indicoio
    political_IND = indicoio.political(text)
    sentiment_IND = indicoio.sentiment_hq(text)
    personality_IND = indicoio.personality(text)
    emotion_IND = indicoio.emotion(text)
    personas_IND = indicoio.personas(text)
    people_IND = []
    places_IND = []
    organizations_IND = []
    
    people = indicoio.people(text)
    places = indicoio.places(text)
    things = indicoio.organizations(text)
    
    for p in range(len(people)):
        people_IND.append(people[p]['text'])
    
    for p in range(len(places)):
        places_IND.append(places[p]['text'])
   
    for t in range(len(things)):
        organizations_IND.append(things[t]['text'])
    
    #update the db
    debateCOL.update_one({'_id': id}, {'$set': {'text': text} } )
    debateCOL.update_one({'_id': id}, {'$set': {'political_IND': political_IND}})
    debateCOL.update_one({'_id': id}, {'$set': {'sentiment_IND': float(sentiment_IND)}})
    debateCOL.update_one({'_id': id}, {'$set': {'personality_IND': personality_IND}})
    debateCOL.update_one({'_id': id}, {'$set': {'emotion_IND': emotion_IND}})
    debateCOL.update_one({'_id': id}, {'$set': {'personas_IND': personas_IND}})
    debateCOL.update_one({'_id': id}, {'$set': {'people_IND': people_IND}})
    debateCOL.update_one({'_id': id}, {'$set': {'places_IND': places_IND}})
    debateCOL.update_one({'_id': id}, {'$set': {'organizations_IND': organizations_IND}})
# Out:
# C:\Users\enc82\Anaconda3\lib\site-packages\indicoio\utils\api.py:144: UserWarning: You're out of credits for the month! You're running into your grace credits now.
#   warnings.warn(warning)

# %%
results = debateCOL.find()

# %%
year = results[0]['year']

year = year.year
print(year)
# Out:
# 2016

# %%
results = debateCOL.find()
text = results[0]['text']

sentences = token.basicNltkSentenceTokenizer(text)

tokens, postags, lemmas = token.basicNltkTokenizeAll(sentences[0])
print(tokens, postags,lemmas)
ngrams = token.computeNltkNgrams(sentences[0],dict(),1, 2)
#print(ngrams)
namedEntities = token.basicNltkNER(sentences[0])
#print(namedEntities)
nounchunks = token.basicNltkNounChunks(sentences[0])
print(nounchunks)

#https://scikit-learn.org/stable/modules/naive_bayes.html#multinomial-naive-bayes
#https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html#sklearn.naive_bayes.MultinomialNB
# Out:
# ['Presidential', 'Debate', 'at', 'Hofstra', 'University', 'in', 'Hempstead', ',', 'New', 'York', 'September', '26', ',', '2016', 'PARTICIPANTS', ':', 'Former', 'Secretary', 'of', 'State', 'Hillary', 'Clinton', '(', 'D', ')', 'and', 'Businessman', 'Donald', 'Trump', '(', 'R', ')', 'MODERATOR', ':', 'Lester', 'Holt', '(', 'NBC', 'News', ')', 'HOLT', ':', 'Good', 'evening', 'from', 'Hofstra', 'University', 'in', 'Hempstead', ',', 'New', 'York', '.'] ['JJ', 'NN', 'IN', 'NNP', 'NNP', 'IN', 'NNP', ',', 'NNP', 'NNP', 'NNP', 'CD', ',', 'CD', 'NN', ':', 'NNP', 'NNP', 'IN', 'NNP', 'NNP', 'NNP', '(', 'NNP', ')', 'CC', 'NNP', 'NNP', 'NNP', '(', 'NNP', ')', 'NN', ':', 'NNP', 'NNP', '(', 'NNP', 'NNP', ')', 'NN', ':', 'JJ', 'NN', 'IN', 'NNP', 'NNP', 'IN', 'NNP', ',', 'NNP', 'NNP', '.'] ['Presidential', 'Debate', 'at', 'Hofstra', 'University', 'in', 'Hempstead', ',', 'New', 'York', 'September', '26', ',', '2016', 'PARTICIPANTS', ':', 'Former', 'Secretary', 'of', 'State', 'Hillary', 'Clinton', '(', 'D', ')', 'and', 'Businessman', 'Donald', 'Trump', '(', 'R', ')', 'MODERATOR', ':', 'Lester', 'Holt', '(', 'NBC', 'News', ')', 'HOLT', ':', 'Good', 'evening', 'from', 'Hofstra', 'University', 'in', 'Hempstead', ',', 'New', 'York', '.']
# ['Presidential Debate', 'Hofstra University', 'Hempstead', 'New York September', 'PARTICIPANTS', 'Former Secretary', 'State Hillary Clinton', 'D', 'Businessman Donald Trump', 'R', 'MODERATOR', 'Lester Holt', 'NBC News', 'HOLT', 'Good evening', 'Hofstra University', 'Hempstead', 'New York']

# %%
corpus = token.basicNltkSentenceTokenizer(df2['text'])

vocab = vectorizer.vocabulary_

vectorizer = CountVectorizer()
print( vectorizer.fit_transform(corpus).todense() )
print( vectorizer.vocabulary_ )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-342-61375157a0d2> in <module>()
#       2 from sklearn.feature_extraction.text import CountVectorizer
#       3
# ----> 4 corpus = token.basicNltkSentenceTokenizer(df2['text'])
#       5
#       6 vocab = vectorizer.vocabulary_
#
# ~\Documents\GitHub\Final_Project\Erin\tokenization.py in basicNltkSentenceTokenizer(beginer)
#     165 def basicNltkSentenceTokenizer(beginer):
#     166
# --> 167     result = nk.tokenize.sent_tokenize(beginer)
#     168     return result
#     169
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
#      93     """
#      94     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 95     return tokenizer.tokenize(text)
#      96
#      97 # Standard word tokenizer.
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py in tokenize(self, text, realign_boundaries)
#    1239         Given a text, returns a list of the sentences in that text.
#    1240         """
# -> 1241         return list(self.sentences_from_text(text, realign_boundaries))
#    1242
#    1243     def debug_decisions(self, text):
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1289         follows the period.
#    1290         """
# -> 1291         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1292
#    1293     def _slices_from_text(self, text):
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py in <listcomp>(.0)
#    1289         follows the period.
#    1290         """
# -> 1291         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1292
#    1293     def _slices_from_text(self, text):
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py in span_tokenize(self, text, realign_boundaries)
#    1279         if realign_boundaries:
#    1280             slices = self._realign_boundaries(text, slices)
# -> 1281         for sl in slices:
#    1282             yield (sl.start, sl.stop)
#    1283
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py in _realign_boundaries(self, text, slices)
#    1320         """
#    1321         realign = 0
# -> 1322         for sl1, sl2 in _pair_iter(slices):
#    1323             sl1 = slice(sl1.start + realign, sl1.stop)
#    1324             if not sl2:
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py in _pair_iter(it)
#     311     """
#     312     it = iter(it)
# --> 313     prev = next(it)
#     314     for el in it:
#     315         yield (prev, el)
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py in _slices_from_text(self, text)
#    1293     def _slices_from_text(self, text):
#    1294         last_break = 0
# -> 1295         for match in self._lang_vars.period_context_re().finditer(text):
#    1296             context = match.group() + match.group('after_tok')
#    1297             if self.text_contains_sentbreak(context):
#
# TypeError: expected string or bytes-like object

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
y = []
for r in range(0,41):
    d = 
    year = results[r]['year']
    text = results[r]['text']
    y.append({"year", year.year)

print(y)
# Out:
# [2016, 2016, 2016, 2016, 2012, 2012, 2012, 2012, 2008, 2008, 2004, 2004, 2004, 2004, 2000, 2000, 2000, 2000, 1996, 1996, 1996, 1992, 1992, 1992, 1992, 1992, 1992, 1988, 1988, 1988, 1984, 1984, 1984, 1980, 1980, 1976, 1976, 1976, 1960, 1960, 1960]

# %%
results = debateCOL.find()
X =[]
for x in range(0,41):
    text = results[r]['text']
    X.append(text)

# %%
results2 = presidential_speech.find()

print(results2[0])
# Out:
# {'_id': ObjectId('5d3cbbee101b81f283a27035'), 'year': 2019, 'hash': '566db0ebbcf046860d0463ed5dac65f6', 'text': 'Madam Speaker, Mr. Vice President, Members of Congress, the\xa0First Lady of the United States, and my fellow Americans:\nWe meet tonight at a moment of unlimited potential.\xa0As we begin a new Congress, I stand here ready to work with you to achieve historic breakthroughs for all Americans.\nMillions of our fellow citizens are watching us now, gathered in this great chamber, hoping that we will govern not as two parties but as one Nation.\nThe agenda I will lay out this evening is not a Republican agenda or a Democrat agenda.\xa0It is the agenda of the American people.\nMany of us campaigned on the same core promises:\xa0to defend American jobs and demand fair trade for American workers; to rebuild and revitalize our Nation’s infrastructure; to reduce the price of healthcare and prescription drugs; to create an immigration system that is safe, lawful, modern, and secure; and to pursue a foreign policy that puts America’s interests first.\nThere is a new opportunity in American politics, if only we have the courage to seize it.\xa0Victory is not winning for our party.\xa0Victory is winning for our country.\nThis year, America will recognize two important anniversaries that show us the majesty of America’s mission, and\xa0the power of American pride.\nIn June, we mark 75 years since the start of what General Dwight D. Eisenhower called the Great Crusade—the Allied liberation of Europe in World War II.\xa0On D-Day, June 6, 1944, 15,000 young American men jumped from the sky, and 60,000 more stormed in from the sea, to save our civilization from tyranny.\xa0Here with us tonight are three of those heroes:\xa0Private First Class Joseph Reilly, Staff Sergeant Irving Locker, and Sergeant Herman Zeitchik.\xa0Gentlemen, we salute you.\nIn 2019, we also celebrate 50 years since brave young pilots flew a quarter of a million miles through space to plant the American flag on the face of the moon.\xa0Half a century later, we are joined by one of the Apollo 11 astronauts who planted that flag:\xa0Buzz Aldrin. This year, American astronauts will go back to space on American rockets.\nIn the 20th century, America saved freedom, transformed science, and redefined the middle class standard of living for the entire world to see.\xa0Now, we must step boldly and bravely into the next chapter of this great American adventure, and we must create a new standard of living for the 21st century.\xa0An amazing quality of life for all of our citizens is within our reach.\nWe can make our communities safer, our families stronger, our culture richer, our faith deeper, and our middle class bigger and more prosperous than ever before.\nBut we must reject the politics of revenge, resistance, and\xa0retribution—and embrace the boundless potential of cooperation, compromise, and the common good.\nTogether, we can break decades of political stalemate.\xa0We can bridge old divisions, heal old wounds, build new coalitions, forge new solutions, and unlock the extraordinary promise of America’s future.\xa0The decision is ours to make.\nWe must choose between greatness or gridlock, results or resistance, vision or vengeance, incredible progress or pointless destruction.\nTonight, I ask you to choose greatness.\nOver the last 2 years, my administration has moved with urgency and historic speed to confront problems neglected by leaders of both parties over many decades.\nIn just over 2 years since the election, we have launched an unprecedented economic boom—a boom that has rarely been seen before.\xa0We have created 5.3 million new jobs and importantly added 600,000 new manufacturing jobs—something which almost everyone said was impossible to do, but the fact is, we are just getting started.\nWages are rising at the fastest pace in decades, and growing for blue collar workers, who I promised to fight for, faster than anyone else.\xa0Nearly 5 million America ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MaxAbsScaler
from tensorflow.keras.utils import to_categorical
from sklearn.feature_extraction.text import CountVectorizer

X = df2['text']
#X2 = prezDF['text']
tf_vectorizer = CountVectorizer(min_df=2, max_df = .95 ,ngram_range = (1,3), stop_words='english')
tf_vectorizer.fit(X)
tf = tf_vectorizer.transform(X)
y = df2['decade'].to_string()
#y2 = prezDF['president']



X_train, X_test, y_train, y_test = train_test_split(tf, y, random_state=1, stratify=y)
X_scaler = MaxAbsScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)


# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-395-db475a1b731a> in <module>()
#      13
#      14
# ---> 15 X_train, X_test, y_train, y_test = train_test_split(tf, y, random_state=1, stratify=y)
#      16 X_scaler = MaxAbsScaler().fit(X_train)
#      17 X_train_scaled = X_scaler.transform(X_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2029         test_size = 0.25
#    2030
# -> 2031     arrays = indexable(*arrays)
#    2032
#    2033     if shuffle is False:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py
ause.)  Thank...  speech    2010\n37    2012   Mr. Speaker, Mr. Vice President, members of C...  speech    2010\n38    2011  Good afternoon, everybody.  As a candidate for...  speech    2010\n39    2011  Mr. Speaker, Mr. Vice President, members of Co...  speech    2010\n40    2011  Good evening.  Nearly 10 years ago, America su...  speech    2010\n41    2011  Thank you very much.  Thank you.  (Applause.) ...  speech    2010\n42    2011  Thank you.  Thank you.  (Applause.)  Thank you...  speech    2010\n43    2011  ood evening.  Tonight, I can report to the Ame...  speech    2010\n44    2011  Mr. Speaker, Mr. Vice President, members of Co...  speech    2010\n45    2011  Thank you.  (Applause.)  Thank you very much. ...  speech    2010\n46    2010  THE PRESIDENT: Good afternoon, everybody.  Las...  speech    2000\n47    2010  THE PRESIDENT:  Mr. President, Mr. Secretary-G...  speech    2000\n48    2010  Good evening.  Tonight, I’d like to talk to yo...  speech    2000\n49    2010  Good evening.  As we speak, our natio ...

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X_train_scaled, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# Out:
# 0.669260700389105

# %%
year =[]
text = []
type_speech = []
president = []

# %%
for r in range(0,986):
    year.append(results[r]['year'])
    
    text.append(results[r]['text'])
    type_speech.append(results[r]['tag'])
    president.append("")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-128-ff01f839e530> in <module>()
#       1 for r in range(0,986):
# ----> 2     year.append(results[r]['year'])
#       3
#       4     text.append(results[r]['text'])
#       5     type_speech.append(results[r]['tag'])
#
# ~\Anaconda3\lib\site-packages\pymongo\cursor.py in __getitem__(self, index)
#     611             for doc in clone:
#     612                 return doc
# --> 613             raise IndexError("no such item for Cursor instance")
#     614         raise TypeError("index %r cannot be applied to Cursor "
#     615                         "instances" % index)
#
# IndexError: no such item for Cursor instance

# %%
for x in range(len(df['year'])):
    print(df['year'][x])
    if type(df['year'][x]) == type(32):
        print("y")
    else:
        y = df['year'][x].year
        df['year'][x] = y
        print(df['year'][x])
        
        
#df['decade']= pd.DataFrame({"year":year,'text':text,"tag":type_speech,"president":president})
# Out:
# 2019
# y
# 2019
# y
# 2018
# y
# 2018
# y
# 2018
# y
# 2018
# y
# 2018
# y
# 2018
# y
# 2018
# y
# 2018
# y
# 2017
# y
# 2017
# y
# 2017
# y
# 2017
# y
# 2017
# y
# 2017
# y
# 2016
# y
# 2016
# y
# 2016
# y
# 2015
# y
# 2015
# y
# 2015
# y
# 2014
# y
# 2014
# y
# 2013
# y
# 2013
# y
# 2013
# y
# 2013
# y
# 2013
# y
# 2013
# y
# 2013
# y
# 2013
# y
# 2013
# y
# 2013
# y
# 2012
# y
# 2012
# y
# 2012
# y
# 2012
# y
# 2011
# y
# 2011
# y
# 2011
# y
# 2011
# y
# 2011
# y
# 2011
# y
# 2011
# y
# 2011
# y
# 2010
# y
# 2010
# y
# 2010
# y
# 2010
# y
# 2010
# y
# 2010
# y
# 2010
# y
# 2010
# y
# 2010
# y
# 2009
# y
# 2009
# y
# 2009
# y
# 2009
# y
# 2009
# y
# 2009
# y
# 2009
# y
# 2009
# y
# 2009
# y
# 2009
# y
# 2009
# y
# 2008
# y
# 2008
# y
# 2008
# y
# 2008
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_numeric'

# %%
bins = [1770]
start = 1770

for x in range(0,25):
    start +=10
    bins.append(start)
    
print(bins)
# Create the bins in which Data will be held
# Bins are 0, 59, 69, 79, 89, 100.   
#bins = [0, 59, 69, 79, 89, 100]

# Create the names for the four bins
group_names = []
start = 1760
for x in range(0,25):
    start +=10
    group_names.append(start)
#pd.cut(df["Test Score"], bins, labels=group_names)
# Out:
# [1770, 1780, 1790, 1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]

# %%
df['decade'] = pd.cut(df['year'], bins, labels=group_names)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029 entries, 0 to 1028
# Data columns (total 5 columns):
# year         1029 non-null object
# text         1029 non-null object
# tag          1029 non-null object
# president    1029 non-null object
# decade       1029 non-null category
# dtypes: category(1), object(4)
# memory usage: 34.1+ KB
#    year                                               text     tag  \
# 0  2019  Madam Speaker, Mr. Vice President, Members of ...  speech
# 1  2019  THE PRESIDENT: Just a short time ago, I had th...  speech
# 2  2018  THE PRESIDENT: Madam President, Mr. Secretary-...  speech
# 3  2018  THE PRESIDENT: Thank you, Lee. Thank you, Lee....  speech
# 4  2018  THE PRESIDENT: Thank you to our First Lady, Me...  speech
#
#       president decade
# 0  Donald Trump   2010
# 1  Donald Trump   2010
# 2  Donald Trump   2010
# 3  Donald Trump   2010
# 4  Donald Trump   2010

# %%
df.to_csv("all.csv")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
no_features = 10000
# LDA can only use raw term counts for LDA because it is a probabilistic graphical model
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf_vectorizer.fit(X)
tf = tf_vectorizer.transform(X)
tf_feature_names = tf_vectorizer.get_feature_names()

no_topics = 10

# Run LDA
lda = LatentDirichletAllocation(n_topics=no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)

def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic :" + str(topic_idx))
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 10
display_topics(lda, tf_feature_names, no_top_words)
# Out:
# C:\Users\enc82\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# Topic :0
# iraq war people world america security peace nations forces troops
# Topic :1
# mr president united world states people kennedy america senator believe
# Topic :2
# states government united congress public state shall great country 000
# Topic :3
# think president mr ve people going senator don question said
# Topic :4
# uh mr government people president states country congress think federal
# Topic :5
# chilean sailors police people egan valparaiso baltimore assault americans united
# Topic :6
# trump going clinton people applause want know just ve said
# Topic :7
# people america new american work years applause nation americans world
# Topic :8
# people health care ve want bush going make know just
# Topic :9
# panama 1903 november colon telegram hay isthmus washington ehrman loomis

# %%
df.head(1000)
# Out:
#      year                                               text     tag  \
# 0    2019  Madam Speaker, Mr. Vice President, Members of ...  speech
# 1    2019  THE PRESIDENT: Just a short time ago, I had th...  speech
# 2    2018  THE PRESIDENT: Madam President, Mr. Secretary-...  speech
# 3    2018  THE PRESIDENT: Thank you, Lee. Thank you, Lee....  speech
# 4    2018  THE PRESIDENT: Thank you to our First Lady, Me...  speech
# 5    2018  THE PRESIDENT: Thank you very much. Thank you ...  speech
# 6    2018  THE PRESIDENT: My fellow Americans, today I sp...  speech
# 7    2018  THE PRESIDENT: Thank you, Paul and Mitch, for ...  speech
# 8    2018  Mr. Speaker, Mr. Vice President, Members of Co...  speech
# 996  2008   October 15, 2008 The Third McCain-Obama Presi...  debate
# 997  2004   October 13, 2004 The Third Bush-Kerry Preside...  debate
# 998  2004   October 8, 2004 The Second Bush-Kerry Preside...  debate
# 999  2004   October 5, 2004 The Cheney-Edwards Vice Presi...  debate
#
#              president  decade
# 0         Donald Trump    2010
# 1         Donald Trump    2010
# 2         Donald Trump    2010
# 3         Donald Trump    2010
# 4         Donald Trump    2010
# 5         Donald Trump    2010
# 6         Donald Trump    2010
# 7         Donald Trump    2010
# 8         Donald Trump    2010
# 9         Donald Trump    2010
# 10        Donald Trump    2010
# 11        Donald Trump    2010
# 12        Donald Trump    2010
# 13        Donald Trump    2010
# 14        Donald Trump    2010
# 15        Donald Trump    2010
# 16        Barack Obama    2010
# 17        Barack Obama    2010
# 18        Barack Obama    2010
# 19        Barack Obama    2010
# 20        Barack Obama    2010
# 21        Barack Obama    2010
# 22        Barack Obama    2010
# 23        Barack Obama    2010
# 24        Barack Obama    2010
# 25        Barack Obama    2010
# 26        Barack Obama    2010
# 27        Barack Obama    2010
# 28        Barack Obama    2010
# 29        Barack Obama    2010
# ..                 ...     ...
# 970  George Washington    1790
# 971  George Washington    1790
# 972  George Washington    1790
# 973  George Washington    1790
# 974  George Washington    1790
# 975  George Washington    1790
# 976  George Washington    1790
# 977  George Washington    1790
# 978  George Washington    1790
# 979  George Washington    1790
# 980  George Washington    1790
# 981  George Washington    1790
# 982  George Washington    1780
# 983  George Washington    1780
# 984  George Washington    1780
# 985  George Washington    1780
# 986                NaN    2010
# 987                NaN    2010
# 988                NaN    2010
# 989                NaN    2010
# 990                NaN    2010
# 991                NaN    2010
# 992                NaN    2010
# 993                NaN    2010
# 994                NaN    2010
# 995                NaN    2000
# 996                NaN    2000
# 997                NaN    2000
# 998                NaN    2000
# 999                NaN    2000
#
# [1000 rows x 5 columns]

# %%
df2 = df.drop(columns = 'president')

# %%
df2 = df2.dropna()

# %%
political_IND = []
sentiment_IND = []
personality_IND = []
emotion_IND = []
personas_IND = []

people_IND = []
places_IND = []
organizations_IND = []


for x in df2['text']:
    t = x
    
    political_IND.append(indicoio.political(t))
    sentiment_IND.append(indicoio.sentiment(t))
    personality_IND.append(indicoio.personality(t))
    emotion_IND.append(indicoio.emotion(t))
    personas_IND.append(indicoio.personas(t))

# %%
df2['political_IND'] = political_IND
df2['sentiment_IND'] = sentiment_IND
df2['personality_IND'] = personality_IND
df2['emotion_IND'] = emotion_IND
df2['personas_IND'] = personas_IND

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1028 entries, 0 to 1028
# Data columns (total 11 columns):
# year               1028 non-null int64
# text               1028 non-null object
# tag                1028 non-null object
# decade             1028 non-null int64
# political_IND      1028 non-null object
# sentiment_IND      1028 non-null float64
# personality_IND    1028 non-null object
# emotion_IND        1028 non-null object
# personas_IND       1028 non-null object
# liberal            1028 non-null float64
# conservative       1028 non-null float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 136.4+ KB

# %%
liberal = []
conservative = []
for x in df2['political_IND']:
    c = x["Conservative"]+x["Libertarian"]/2
    l = x["Liberal"]+x["Green"]/2
    conservative.append(c)
    liberal.append(l)

# %%
df2['liberal'] = liberal
df2['conservative'] = conservative

# %%
df2.groupby('decade').count()
# Out:
#         year  text  tag  political_IND  sentiment_IND  personality_IND  \
# decade
# 1780       4     4    4              4              4                4
# 1790      25    25   25             25             25               25
# 1800      29    29   29             29             29               29
# 1810      22    22   22             22             22               22
# 1820      20    20   20             20             20               20
# 1830      28    28   28             28             28               28
# 1840      54    54   54             54             54               54
# 1850      33    33   33             33             33               33
# 1860      57    57   57             57             57               57
# 1870      35    35   35             35             35               35
# 1880      37    37   37             37             37               37
# 1890      39    39   39             39             39               39
# 1900      32    32   32             32             32               32
# 1910      48    48   48             48             48               48
# 1920      35    35   35             35             35               35
# 1930      36    36   36             36             36               36
# 1940      39    39   39             39             39               39
# 1950      21    21   21             21             21               21
# 1960     115   115  115            115            115              115
# 1970      61    61   61             61             61               61
# 1980      75    75   75             75             75               75
# 1990      62    62   62             62             62               62
# 2000      66    66   66             66             66               66
# 2010      55    55   55             55             55               55
#
#         emotion_IND  personas_IND  liberal  conservative
# decade
# 1780              4             4        4             4
# 1790             25            25       25            25
# 1800             29            29       29            29
# 1810             22            22       22            22
# 1820             20            20       20            20
# 1830             28            28       28            28
# 1840             54            54       54            54
# 1850             33            33       33            33
# 1860             57            57       57            57
# 1870             35            35       35            35
# 1880             37            37       37            37
# 1890             39            39       39            39
# 1900             32            32       32            32
# 1910             48            48       48            48
# 1920             35            35       35            35
# 1930             36            36       36            36
# 1940             39            39       39            39
# 1950             21            21       21            21
# 1960            115           115      115           115
# 1970             61            61       61            61
# 1980             75            75       75            75
# 1990             62            62       62            62
# 2000             66            66       66            66
# 2010             55            55       55            55

# %%
clean = speechDB.clean

for x in range(0,1028):
    if x != 554:
        post = {
            'year':int(df2['year'][x]),
            'text': df2['text'][x],
            'tag': df2['tag'][x],
            'decade': int(df2['decade'][x]),
            'sentiment_IND': float(df2['sentiment_IND'][x]),
            'personality_IND': df2['personality_IND'][x],
            'emotion_IND': df2['emotion_IND'][x],
            'personas_IND': df2['personas_IND'][x],
            'liberal': float(df2['liberal'][x]),
            'conservative': float(df2['conservative'][x])
        }
        clean.insert_one(post)

# %%
speechDB.clean.drop
# Out:
# <bound method Collection.drop of Collection(Database(MongoClient(host=['timanderin.info:27017'], document_class=dict, tz_aware=False, connect=True), 'speech_db'), 'clean')>

# %%
results = clean.find({'decade':1790})
print(results)
# Out:
# <pymongo.cursor.Cursor object at 0x000002CEDB7EEE48>

# %%
print(results[0])
# Out:
# {'_id': ObjectId('5d4235861c2d559d7a9caec4'), 'year': 1800, 'text': 'Gentlemen of the Senate and Gentlemen of the House of Representatives: Immediately after the adjournment of Congress at their last session in Philadelphia I gave directions, in compliance with the laws, for the removal of the public offices, records, and property. These directions have been executed, and the public officers have since resided and conducted the ordinary business of the Government in this place.  I congratulate the people of the United States on the assembling of Congress at the permanent seat of their Government, and I congratulate you, gentlemen, on the prospect of a residence not to be changed. Although there is cause to apprehend that accommodations are not now so complete as might be wished, yet there is great reason to believe that this inconvenience will cease with the present session.  It would be unbecoming the representatives of this nation to assemble for the first time in this solemn temple without looking up to the Supreme Ruler of the Universe and imploring His blessing.  May this territory be the residence of virtue and happiness! In this city may that piety and virtue, that wisdom and magnanimity, that constancy and self-government, which adorned the great character whose name it bears be forever held in veneration! Here and throughout our country may simple manners, pure morals, and true religion flourish forever!  It is with you, gentlemen, to consider whether the local powers over the District of Columbia vested by the Constitution in the Congress of the United States shall be immediately exercised. If in your opinion this important trust ought now to be executed, you can not fail while performing it to take into view the future probable situation of the territory for the happiness of which you are about to provide. You will consider it as the capital of a great nation advancing with unexampled rapidity in arts, in commerce, in wealth, and in population, and possessing within itself those energies and resources which, if not thrown away or lamentably misdirected, will secure to it a long course of prosperity and self-government.  In compliance with a law of the last session of Congress, the officers and soldiers of the temporary army have been discharged. It affords real pleasure to recollect the honorable testimony they gave of the patriotic motives which brought them into the service of their country, by the readiness and regularity with which they returned to the station of private citizens.  It is in every point of view of such primary importance to carry the laws into prompt and faithful execution, and to render that part of the administration of justice which the Constitution and laws devolve on the Federal courts as convenient to the people as may consist with their present circumstances, that I can not omit once more to recommend to your serious consideration the judiciary system of the United States. No subject is more interesting than this to the public happiness, and to none can those improvements which may have been suggested by experience be more beneficially applied.  A treaty of amity and commerce with the King of Prussia has been concluded and ratified. The ratifications have been exchanged, and I have directed the treaty to be promulgated by proclamation.  The difficulties which suspended the execution of the 6th article of our treaty of amity, commerce, and navigation with Great Britain have not yet been removed. The negotiation on this subject is still depending. As it must be fore the interest and honor of both nations to adjust this difference with good faith, I indulge confidently the expectation that the sincere endeavors of the Government of the United States to bring it to an amicable termination will not be disappointed.  The envoys extraordinary and ministers plenipotentiary from the United States to France were received by the First Consul with the respect due to their character, and 3 persons with ...

# %%
import pymongo

conn = 'mongodb://timanderin.info:27017'
client = pymongo.MongoClient(conn)
speechDB = client.speech_db
debateCOL = speechDB.presidential_debates
presidential_speech = speechDB.presidential_speech
import tokenization as token
clean = speechDB.clean

import pandas as pd

# %%
results = clean.find()
#1025
#1780 - 2010

# %%
decade= []
liberal = []
conservative = []
for x in range(0,1023):
    if x!=554:
        decade.append(results[x]['decade'])
        liberal.append(results[x]['liberal'])
        conservative.append(results[x]['conservative'])

# %%
df = pd.DataFrame({"decade":decade,"liberal":liberal,"conservative":conservative})
df = df.groupby('decade').aggregate("mean")

# %%
df.head(100)
# Out:
#          liberal  conservative
# decade
# 1780    0.255302      0.417709
# 1790    0.209703      0.460939
# 1800    0.253453      0.418525
# 1810    0.289424      0.413289
# 1820    0.185074      0.524698
# 1830    0.205962      0.502861
# 1840    0.190236      0.478011
# 1850    0.206662      0.473191
# 1860    0.192772      0.489283
# 1870    0.174394      0.477336
# 1880    0.294085      0.399141
# 1890    0.219653      0.448961
# 1900    0.296779      0.392746
# 1910    0.260942      0.449663
# 1920    0.320642      0.396239
# 1930    0.412241      0.318041
# 1940    0.382491      0.364118
# 1950    0.340932      0.394353
# 1960    0.385033      0.366978
# 1970    0.386275      0.343488
# 1980    0.354346      0.398821
# 1990    0.515832      0.288688
# 2000    0.387851      0.360157
# 2010    0.507770      0.337990

# %%
df.to_csv("jdbar.csv")
