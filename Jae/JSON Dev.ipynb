# %%
import pymongo
import pandas as pd
import nltk
import os
conn = 'mongodb://timanderin.info:27017'
client = pymongo.MongoClient(conn)
speechDB = client.speech_db
col = speechDB.clean

# %%
test = col.find()
i= 0

finalData = dict()

while i < col.count():
    finalData[i] =test[i]
    finalData[i]['_id']=str(test[i]['_id'])
    finalData[i].pop('text')
    i=i+1
# Out:
# /Users/Jae/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-2ca9ce6a71e7> in <module>
#       6 while i < col.count():
#       7     finalData[i] =test[i]
# ----> 8     finalData[i]['_id']=str(test[i]['_id'])
#       9     finalData[i].pop('text')
#      10     i=i+1
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in __getitem__(self, index)
#     608             clone.limit(-1)  # use a hard limit
#     609             clone.__query_flags &= ~CursorType.TAILABLE_AWAIT  # PYTHON-1371
# --> 610             for doc in clone:
#     611                 return doc
#     612             raise IndexError("no such item for Cursor instance")
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1187         if self.__empty:
#    1188             raise StopIteration
# -> 1189         if len(self.__data) or self._refresh():
#    1190             if self.__manipulate:
#    1191                 _db = self.__collection.database
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1102                                   self.__session,
#    1103                                   self.__collection.database.client)
# -> 1104             self.__send_message(q)
#    1105         elif self.__id:  # Get More
#    1106             if self.__limit:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in __send_message(self, operation)
#     929             try:
#     930                 response = client._send_message_with_response(
# --> 931                     operation, exhaust=self.__exhaust, address=self.__address)
#     932                 self.__address = response.address
#     933                 if self.__exhaust:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/mongo_client.py in _send_message_with_response(self, operation, exhaust, address)
#    1143             self.__all_credentials,
#    1144             self._event_listeners,
# -> 1145             exhaust)
#    1146
#    1147     def _reset_on_error(self, server, func, *args, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/mongo_client.py in _reset_on_error(self, server, func, *args, **kwargs)
#    1154         """
#    1155         try:
# -> 1156             return func(*args, **kwargs)
#    1157         except NetworkTimeout:
#    1158             # The socket has been closed. Don't reset the server.
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/server.py in send_message_with_response(self, operation, set_slave_okay, all_credentials, listeners, exhaust)
#     104             try:
#     105                 sock_info.send_message(data, max_doc_size)
# --> 106                 reply = sock_info.receive_message(request_id)
#     107             except Exception as exc:
#     108                 if publish:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in receive_message(self, request_id)
#     610                                    self.max_message_size)
#     611         except BaseException as error:
# --> 612             self._raise_connection_failure(error)
#     613
#     614     def _raise_if_not_writable(self, unacknowledged):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in _raise_connection_failure(self, error)
#     743             _raise_connection_failure(self.address, error)
#     744         else:
# --> 745             raise error
#     746
#     747     def __eq__(self, other):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in receive_message(self, request_id)
#     608         try:
#     609             return receive_message(self.sock, request_id,
# --> 610                                    self.max_message_size)
#     611         except BaseException as error:
#     612             self._raise_connection_failure(error)
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/network.py in receive_message(sock, request_id, max_message_size)
#     189             _receive_data_on_socket(sock, length - 25), compressor_id)
#     190     else:
# --> 191         data = _receive_data_on_socket(sock, length - 16)
#     192
#     193     try:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/network.py in _receive_data_on_socket(sock, length)
#     230         while bytes_read < length:
#     231             try:
# --> 232                 chunk_length = sock.recv_into(mv[bytes_read:])
#     233             except (IOError, OSError) as exc:
#     234                 if _errno_from_exception(exc) == errno.EINTR:
#
# KeyboardInterrupt:

# %%
finalData
# Out:
# {0: {'_id': '5d436e42a8a0d417d6e46c94',
#   'year': 2019,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.999975542014268,
#   'personality_IND': {'extraversion': 0.5152927508293571,
#    'openness': 0.6724623664517269,
#    'agreeableness': 0.49788615264390645,
#    'conscientiousness': 0.48032327373137423},
#   'emotion_IND': {'fear': 0.35817867517471313,
#    'anger': 0.3128367066383362,
#    'sadness': 0.19470757246017456,
#    'joy': 0.12196220457553864,
#    'surprise': 0.012314881198108196},
#   'personas_IND': {'executive': 0.032785411924123764,
#    'entrepreneur': 0.028003990921033346,
#    'consul': 0.028696211565021508,
#    'entertainer': 0.02451116013333105,
#    'commander': 0.11213597269437833,
#    'debater': 0.09578207831339863,
#    'protagonist': 0.09814968127826128,
#    'campaigner': 0.08383554565715944,
#    'logistician': 0.032277910002341356,
#    'virtuoso': 0.027570504177666846,
#    'defender': 0.02825200961775784,
#    'adventurer': 0.024131740535163995,
#    'architect': 0.11040016804586977,
#    'logician': 0.09429942316906473,
#    'advocate': 0.09663037691126061,
#    'mediator': 0.08253781642393149},
#   'liberal': 0.2706161569803953,
#   'conservative': 0.5705181211233139},
#  1: {'_id': '5d436e42a8a0d417d6e46c95',
#   'year': 2019,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9972498840739092,
#   'personality_IND': {'extraversion': 0.48272306661484604,
#    'openness': 0.6736532770027623,
#    'agreeableness': 0.4528239939296454,
#    'conscientiousness': 0.488705622910083},
#   'emotion_IND': {'sadness': 0.3576829433441162,
#    'joy': 0.3566061556339264,
#    'fear': 0.1517040729522705,
#    'anger': 0.09639398753643036,
#    'surprise': 0.03761279210448265},
#   'personas_IND': {'executive': 0.033042822033166885,
#    'entrepreneur': 0.029241558509587824,
#    'consul': 0.0231954193752391,
#    'entertainer': 0.020527007092565205,
#    'commander': 0.11171118188961907,
#    'debater': 0.0988598734030613,
#    'protagonist': 0.07841908365503787,
#    'campaigner': 0.06939771427878456,
#    'logistician': 0.038109635556853025,
#    'virtuoso': 0.033725484618987764,
#    'defender': 0.026752225231569015,
#    'adventurer': 0.023674636279977086,
#    'architect': 0.12884107204313297,
#    'logician': 0.1140191326942039,
#    'advocate': 0.09044393440164737,
#    'mediator': 0.08003922036968907},
#   'liberal': 0.3774978592991829,
#   'conservative': 0.4850682467222214},
#  2: {'_id': '5d436e42a8a0d417d6e46c96',
#   'year': 2018,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9980787217059793,
#   'personality_IND': {'extraversion': 0.5143156776488838,
#    'openness': 0.6967978187810595,
#    'agreeableness': 0.45181038191443995,
#    'conscientiousness': 0.47778498115895807},
#   'emotion_IND': {'joy': 0.351865291595459,
#    'sadness': 0.2944125533103943,
#    'surprise': 0.15162360668182373,
#    'fear': 0.12005458772182465,
#    'anger': 0.08204397559165955},
#   'personas_IND': {'executive': 0.030956687405705452,
#    'entrepreneur': 0.027748101586813432,
#    'consul': 0.02108668817211197,
#    'entertainer': 0.018901104682467883,
#    'commander': 0.12940097990882288,
#    'debater': 0.1159888858462509,
#    'protagonist': 0.08814374055891804,
#    'campaigner': 0.07900785812405446,
#    'logistician': 0.02959617892355918,
#    'virtuoso': 0.02652860759685688,
#    'defender': 0.020159954881420875,
#    'adventurer': 0.018070425023475896,
#    'architect': 0.12371397041018786,
#    'logician': 0.11089132092820697,
#    'advocate': 0.0842699345788011,
#    'mediator': 0.07553556262880472},
#   'liberal': 0.4154086038470268,
#   'conservative': 0.41028793156147003},
#  3: {'_id': '5d436e42a8a0d417d6e46c97',
#   'year': 2018,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9991747650564221,
#   'personality_IND': {'extraversion': 0.4783997929702371,
#    'openness': 0.626333326101303,
#    'agreeableness': 0.5394897706675947,
#    'conscientiousness': 0.4236925843803362},
#   'emotion_IND': {'sadness': 0.6004540920257568,
#    'joy': 0.18300177156925201,
#    'surprise': 0.07547961175441742,
#    'anger': 0.07308554649353027,
#    'fear': 0.06797903031110764},
#   'personas_IND': {'executive': 0.02681756764650345,
#    'entrepreneur': 0.03824370565339784,
#    'consul': 0.033547085975647394,
#    'entertainer': 0.04784046066979999,
#    'commander': 0.04894127381744873,
#    'debater': 0.06979363533670928,
#    'protagonist': 0.06122244288807678,
#    'campaigner': 0.0873074303151778,
#    'logistician': 0.03800401059683967,
#    'virtuoso': 0.05419634288273482,
#    'defender': 0.04754061729086745,
#    'adventurer': 0.06779620242940838,
#    'architect': 0.06935619892505376,
#    'logician': 0.09890672797301964,
#    'advocate': 0.08676022498845012,
#    'mediator': 0.1237260707018189},
#   'liberal': 0.25760147627443075,
#   'conservative': 0.6900442354381084},
#  4: {'_id': '5d436e42a8a0d417d6e46c98',
#   'year': 2018,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9993910460872796,
#   'personality_IND': {'extraversion': 0.47422797194981975,
#    'openness': 0.673594898709627,
#    'agreeableness': 0.5292073592805026,
#    'conscientiousness': 0.4320547364909073},
#   'emotion_IND': {'sadness': 0.5419189929962158,
#    'joy': 0.19670507311820984,
#    'surprise': 0.1463630199432373,
#    'fear': 0.06605511903762817,
#    'anger': 0.048957835882902145},
#   'personas_IND': {'executive': 0.022992849349975586,
#    'entrepreneur': 0.028758211570112654,
#    'consul': 0.026005644591436065,
#    'entertainer': 0.03252645207465413,
#    'commander': 0.06220069960620932,
#    'debater': 0.07779726696017279,
#    'protagonist': 0.0703509698375656,
#    'campaigner': 0.08799118363636203,
#    'logistician': 0.033276215297691376,
#    'virtuoso': 0.04162008821971915,
#    'defender': 0.03763645800669626,
#    'adventurer': 0.047073643697248486,
#    'architect': 0.09001945752527689,
#    'logician': 0.11259146300670846,
#    'advocate': 0.10181486994918897,
#    'mediator': 0.12734452615644867},
#   'liberal': 0.1745554143562913,
#   'conservative': 0.45273108035326004},
#  5: {'_id': '5d436e43a8a0d417d6e46c99',
#   'year': 2018,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.4632027065026062,
#   'personality_IND': {'extraversion': 0.4418109968557197,
#    'openness': 0.5862775263942289,
#    'agreeableness': 0.6271012650247205,
#    'conscientiousness': 0.42269062721866296},
#   'emotion_IND': {'joy': 0.5561728477478027,
#    'sadness': 0.21797055006027222,
#    'fear': 0.1192246675491333,
#    'anger': 0.05810990184545517,
#    'surprise': 0.048522092401981354},
#   'personas_IND': {'executive': 0.018526127561926842,
#    'entrepreneur': 0.026070808092749455,
#    'consul': 0.039408128621026293,
#    'entertainer': 0.05545690674871689,
#    'commander': 0.025689223240468812,
#    'debater': 0.03615104059860197,
#    'protagonist': 0.05464521286127135,
#    'campaigner': 0.07689922307791101,
#    'logistician': 0.03713351850743379,
#    'virtuoso': 0.05225597218589464,
#    'defender': 0.07898911555761183,
#    'adventurer': 0.11115706756257594,
#    'architect': 0.05149112871205995,
#    'logician': 0.07246065274582231,
#    'advocate': 0.109530119404509,
#    'mediator': 0.15413575398124282},
#   'liberal': 0.5086223147809505,
#   'conservative': 0.42564769461750984},
#  6: {'_id': '5d436e43a8a0d417d6e46c9a',
#   'year': 2018,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9941195220361534,
#   'personality_IND': {'extraversion': 0.5858693686077151,
#    'openness': 0.6151756867070064,
#    'agreeableness': 0.6732861598332723,
#    'conscientiousness': 0.4466561332516286},
#   'emotion_IND': {'sadness': 0.42764848470687866,
#    'fear': 0.23615248501300812,
#    'anger': 0.21369946002960205,
#    'joy': 0.10874859243631363,
#    'surprise': 0.013750960119068623},
#   'personas_IND': {'executive': 0.02897668443620205,
#    'entrepreneur': 0.025386644863617944,
#    'consul': 0.06722167866055384,
#    'entertainer': 0.058893310465698005,
#    'commander': 0.062211353348661624,
#    'debater': 0.05450373481083466,
#    'protagonist': 0.14432125895079087,
#    'campaigner': 0.12644070900265877,
#    'logistician': 0.022042613563765325,
#    'virtuoso': 0.019311664182644222,
#    'defender': 0.05113564596898179,
#    'adventurer': 0.044800242033861334,
#    'architect': 0.04732428293188625,
#    'logician': 0.04146108432292974,
#    'advocate': 0.10978542860810764,
#    'mediator': 0.09618366367011127},
#   'liberal': 0.5353345423936844,
#   'conservative': 0.30572423338890076},
#  7: {'_id': '5d436e43a8a0d417d6e46c9b',
#   'year': 2018,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9990651299283554,
#   'personality_IND': {'extraversion': 0.46732466453212806,
#    'openness': 0.6695389767116475,
#    'agreeableness': 0.49653027611866324,
#    'conscientiousness': 0.4171047193565588},
#   'emotion_IND': {'joy': 0.4847100079059601,
#    'sadness': 0.35202643275260925,
#    'surprise': 0.06867730617523193,
#    'fear': 0.057917773723602295,
#    'anger': 0.03666849061846733},
#   'personas_IND': {'executive': 0.02360515296459198,
#    'entrepreneur': 0.035600368692895325,
#    'consul': 0.023363273401816292,
#    'entertainer': 0.035235574824834505,
#    'commander': 0.056591548480102,
#    'debater': 0.08534915919653897,
#    'protagonist': 0.05601165982648456,
#    'campaigner': 0.08447459381808385,
#    'logistician': 0.03537362088554155,
#    'virtuoso': 0.05334911097864095,
#    'defender': 0.03501115048245472,
#    'adventurer': 0.05280244729885193,
#    'architect': 0.08480554868300051,
#    'logician': 0.12790041039149527,
#    'advocate': 0.08393655363398952,
#    'mediator': 0.12658982605918775},
#   'liberal': 0.4108349047601223,
#   'conservative': 0.4240887463092804},
#  8: {'_id': '5d436e43a8a0d417d6e46c9c',
#   'year': 2018,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9990232754267561,
#   'personality_IND': {'extraversion': 0.5046399094290653,
#    'openness': 0.655579882525952,
#    'agreeableness': 0.5021353766583558,
#    'conscientiousness': 0.49276941432349985},
#   'emotion_IND': {'sadness': 0.35724419355392456,
#    'joy': 0.3239237666130066,
#    'fear': 0.1800706684589386,
#    'anger': 0.0824320837855339,
#    'surprise': 0.056329283863306046},
#   'personas_IND': {'executive': 0.035292208194732666,
#    'entrepreneur': 0.02826111884305836,
#    'consul': 0.031634271830061976,
#    'entertainer': 0.025331935333324517,
#    'commander': 0.10855249184953887,
#    'debater': 0.086926126151277,
#    'protagonist': 0.09730133895527585,
#    'campaigner': 0.07791648372695004,
#    'logistician': 0.036554412544977925,
#    'virtuoso': 0.029271861217841512,
#    'defender': 0.03276565304718976,
#    'adventurer': 0.02623791717427157,
#    'architect': 0.11243480818704582,
#    'logician': 0.09003498817704289,
#    'advocate': 0.10078126439458279,
#    'mediator': 0.08070312116456421},
#   'liberal': 0.4542653039097786,
#   'conservative': 0.3898029029369354},
#  9: {'_id': '5d436e43a8a0d417d6e46c9d',
#   'year': 2018,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9982993680065319,
#   'personality_IND': {'extraversion': 0.4891605435286538,
#    'openness': 0.7039227396528296,
#    'agreeableness': 0.4744742460418166,
#    'conscientiousness': 0.4456583110765479},
#   'emotion_IND': {'joy': 0.3416825234889984,
#    'surprise': 0.27463871240615845,
#    'sadness': 0.195846825838089,
#    'fear': 0.10900694876909256,
#    'anger': 0.07882501184940338},
#   'personas_IND': {'executive': 0.02452671341598034,
#    'entrepreneur': 0.027865950075943637,
#    'consul': 0.019935668494168255,
#    'entertainer': 0.022649849200444275,
#    'commander': 0.09179236329550144,
#    'debater': 0.10428961471764511,
#    'protagonist': 0.07461016691443631,
#    'campaigner': 0.08476811449419441,
#    'logistician': 0.029924041287473967,
#    'virtuoso': 0.033998108607565476,
#    'defender': 0.024322695647627294,
#    'adventurer': 0.02763415677423688,
#    'architect': 0.11199211683651471,
#    'logician': 0.12723950334184292,
#    'advocate': 0.09102882015766678,
#    'mediator': 0.10342211750103317},
#   'liberal': 0.5152769964188337,
#   'conservative': 0.33149759471416473},
#  10: {'_id': '5d436e43a8a0d417d6e46c9e',
#   'year': 2017,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.999218164178145,
#   'personality_IND': {'extraversion': 0.5088459094197064,
#    'openness': 0.6750577404120258,
#    'agreeableness': 0.4858901019681963,
#    'conscientiousness': 0.4969429238431755},
#   'emotion_IND': {'fear': 0.3038862645626068,
#    'joy': 0.2427016645669937,
#    'anger': 0.22680211067199707,
#    'sadness': 0.19637078046798706,
#    'surprise': 0.030239205807447433},
#   'personas_IND': {'executive': 0.03318879380822182,
#    'entrepreneur': 0.025329992349314583,
#    'consul': 0.026725367623034173,
#    'entertainer': 0.020397046757119737,
#    'commander': 0.12465186242194985,
#    'debater': 0.09513544966136224,
#    'protagonist': 0.10037625874969391,
#    'campaigner': 0.07660808531807256,
#    'logistician': 0.032870012027236335,
#    'virtuoso': 0.02508669596929235,
#    'defender': 0.026468668564156507,
#    'adventurer': 0.020201131670738524,
#    'architect': 0.12345457240811729,
#    'logician': 0.09422166689367724,
#    'advocate': 0.09941213763756748,
#    'mediator': 0.07587225920406168},
#   'liberal': 0.3016256373375654,
#   'conservative': 0.4874413311481476},
#  11: {'_id': '5d436e43a8a0d417d6e46c9f',
#   'year': 2017,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9984942488237507,
#   'personality_IND': {'extraversion': 0.5046202785382837,
#    'openness': 0.6975232613420932,
#    'agreeableness': 0.46332725307397665,
#    'conscientiousness': 0.4784275456064049},
#   'emotion_IND': {'anger': 0.3031593859195709,
#    'sadness': 0.2838493585586548,
#    'joy': 0.20380552113056183,
#    'fear': 0.16110415756702423,
#    'surprise': 0.04808157682418823},
#   'personas_IND': {'executive': 0.02901815064251423,
#    'entrepreneur': 0.025678641273424865,
#    'consul': 0.021086230940423875,
#    'entertainer': 0.01865955421414521,
#    'commander': 0.12222567676435835,
#    'debater': 0.108159521177059,
#    'protagonist': 0.08881609496626416,
#    'campaigner': 0.07859483014266755,
#    'logistician': 0.029933229564124458,
#    'virtuoso': 0.026488409495007015,
#    'defender': 0.021751178884775152,
#    'adventurer': 0.01924797763852404,
#    'architect': 0.12608002668308163,
#    'logician': 0.1115702991141832,
#    'advocate': 0.09161688378148604,
#    'mediator': 0.0810732944489564},
#   'liberal': 0.15037761256098747,
#   'conservative': 0.49418357014656067},
#  12: {'_id': '5d436e43a8a0d417d6e46ca0',
#   'year': 2017,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9928389985128283,
#   'personality_IND': {'extraversion': 0.5244063939583504,
#    'openness': 0.6368476010371591,
#    'agreeableness': 0.5587282792518014,
#    'conscientiousness': 0.4172634232318264},
#   'emotion_IND': {'joy': 0.4387452006340027,
#    'sadness': 0.28117087483406067,
#    'fear': 0.15407335758209229,
#    'surprise': 0.06618830561637878,
#    'anger': 0.05982227623462677},
#   'personas_IND': {'executive': 0.028945330530405045,
#    'entrepreneur': 0.03931583136777978,
#    'consul': 0.03873081456149676,
#    'entertainer': 0.05260724891599516,
#    'commander': 0.05849404990583603,
#    'debater': 0.07945123484596393,
#    'protagonist': 0.07826900605802281,
#    'campaigner': 0.10631114090214003,
#    'logistician': 0.031091694765508042,
#    'virtuoso': 0.042231193541053556,
#    'defender': 0.0416027963506242,
#    'adventurer': 0.05650820123454079,
#    'architect': 0.06283152248429504,
#    'logician': 0.08534273240894412,
#    'advocate': 0.08407283855152302,
#    'mediator': 0.11419436422468372},
#   'liberal': 0.2946060374379158,
#   'conservative': 0.4446439668536186},
#  13: {'_id': '5d436e43a8a0d417d6e46ca1',
#   'year': 2017,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9988611516653287,
#   'personality_IND': {'extraversion': 0.4841518866813789,
#    'openness': 0.6817466162632558,
#    'agreeableness': 0.5400483299765669,
#    'conscientiousness': 0.4357641195428782},
#   'emotion_IND': {'joy': 0.5409163236618042,
#    'sadness': 0.17318227887153625,
#    'surprise': 0.11228470504283905,
#    'fear': 0.10113400220870972,
#    'anger': 0.07248268276453018},
#   'personas_IND': {'executive': 0.022503480315208435,
#    'entrepreneur': 0.02620228463633452,
#    'consul': 0.026372281267760454,
#    'entertainer': 0.03070698343295031,
#    'commander': 0.06749982126154254,
#    'debater': 0.07859448608790416,
#    'protagonist': 0.0791043957415482,
#    'campaigner': 0.09210645620099375,
#    'logistician': 0.030684897237903734,
#    'virtuoso': 0.035728446149934014,
#    'defender': 0.035960247138888596,
#    'adventurer': 0.04187088336906786,
#    'architect': 0.09204020804082699,
#    'logician': 0.1071684741558569,
#    'advocate': 0.10786376770962164,
#    'mediator': 0.125592886502542},
#   'liberal': 0.5954400897026062,
#   'conservative': 0.16430865228176117},
#  14: {'_id': '5d436e44a8a0d417d6e46ca2',
#   'year': 2017,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.999560284524555,
#   'personality_IND': {'extraversion': 0.5241872850110976,
#    'openness': 0.6648388839213646,
#    'agreeableness': 0.5116019489472372,
#    'conscientiousness': 0.480690091505818},
#   'emotion_IND': {'joy': 0.6017840504646301,
#    'fear': 0.14732320606708527,
#    'sadness': 0.1271219551563263,
#    'surprise': 0.06393250823020935,
#    'anger': 0.05983830615878105},
#   'personas_IND': {'executive': 0.03413138538599014,
#    'entrepreneur': 0.028568201054939128,
#    'consul': 0.03199427259738864,
#    'entertainer': 0.026779423946535125,
#    'commander': 0.11084180686790525,
#    'debater': 0.09277534683998014,
#    'protagonist': 0.10390152783534898,
#    'campaigner': 0.08696628604779189,
#    'logistician': 0.032020061803979975,
#    'virtuoso': 0.026801009687997195,
#    'defender': 0.03001514894809197,
#    'adventurer': 0.025122883980333327,
#    'architect': 0.10398527838658732,
#    'logician': 0.08703638582926186,
#    'advocate': 0.09747431589261583,
#    'mediator': 0.08158666590219331},
#   'liberal': 0.2804107628762722,
#   'conservative': 0.45617301762104034},
#  15: {'_id': '5d436e44a8a0d417d6e46ca3',
#   'year': 2017,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9987972886732469,
#   'personality_IND': {'extraversion': 0.5337145452277134,
#    'openness': 0.6584679244834686,
#    'agreeableness': 0.5277427340808667,
#    'conscientiousness': 0.461336580843761},
#   'emotion_IND': {'joy': 0.4836122691631317,
#    'sadness': 0.20897093415260315,
#    'anger': 0.16560088098049164,
#    'fear': 0.09886620938777924,
#    'surprise': 0.04294971376657486},
#   'personas_IND': {'executive': 0.033761460334062576,
#    'entrepreneur': 0.03219304578171331,
#    'consul': 0.03527907594821559,
#    'entertainer': 0.033640160872122925,
#    'commander': 0.09659955257901376,
#    'debater': 0.09211195025921548,
#    'protagonist': 0.10094181553890162,
#    'campaigner': 0.09625249024201162,
#    'logistician': 0.031067236606996458,
#    'virtuoso': 0.029623985584138535,
#    'defender': 0.03246374525722327,
#    'adventurer': 0.030955618411537388,
#    'architect': 0.08889074281565659,
#    'logician': 0.0847612588478934,
#    'advocate': 0.09288648575338525,
#    'mediator': 0.0885713766476381},
#   'liberal': 0.5891690440475941,
#   'conservative': 0.24860666692256927},
#  16: {'_id': '5d436e44a8a0d417d6e46ca4',
#   'year': 2016,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9980005779363817,
#   'personality_IND': {'extraversion': 0.48858125255269524,
#    'openness': 0.6912081283386622,
#    'agreeableness': 0.5152256818194137,
#    'conscientiousness': 0.4243017405956641},
#   'emotion_IND': {'joy': 0.6080669164657593,
#    'sadness': 0.13187053799629211,
#    'surprise': 0.11589715629816055,
#    'fear': 0.10658200085163116,
#    'anger': 0.03758343309164047},
#   'personas_IND': {'executive': 0.022643614560365677,
#    'entrepreneur': 0.02937155531551445,
#    'consul': 0.02357705635475202,
#    'entertainer': 0.030582346237682786,
#    'commander': 0.06943556271465375,
#    'debater': 0.09006647768901314,
#    'protagonist': 0.07229792216778579,
#    'campaigner': 0.09377931047590789,
#    'logistician': 0.029802041744720533,
#    'virtuoso': 0.03865691906204487,
#    'defender': 0.031030578715914883,
#    'adventurer': 0.04025048284089579,
#    'architect': 0.0913865438535391,
#    'logician': 0.11853960407702942,
#    'advocate': 0.09515379405590604,
#    'mediator': 0.1234261916271985},
#   'liberal': 0.5449025183916092,
#   'conservative': 0.23194214701652527},
#  17: {'_id': '5d436e44a8a0d417d6e46ca5',
#   'year': 2016,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9999333994410149,
#   'personality_IND': {'extraversion': 0.5313481039414972,
#    'openness': 0.7023733514491641,
#    'agreeableness': 0.5605008131579349,
#    'conscientiousness': 0.4178678924324869},
#   'emotion_IND': {'anger': 0.3587692677974701,
#    'sadness': 0.2731112837791443,
#    'joy': 0.18370230495929718,
#    'fear': 0.1605614572763443,
#    'surprise': 0.023855693638324738},
#   'personas_IND': {'executive': 0.02153019793331623,
#    'entrepreneur': 0.025654317314945923,
#    'consul': 0.02736540917006476,
#    'entertainer': 0.032607265129665025,
#    'commander': 0.0765033301668208,
#    'debater': 0.0911575761410741,
#    'protagonist': 0.0972376048610937,
#    'campaigner': 0.11586351011874102,
#    'logistician': 0.022596365877747073,
#    'virtuoso': 0.026924709532522257,
#    'defender': 0.028720534017615804,
#    'adventurer': 0.034221964727733895,
#    'architect': 0.08029174652066313,
#    'logician': 0.09567166528564376,
#    'advocate': 0.10205277475841654,
#    'mediator': 0.12160102789202326},
#   'liberal': 0.6844619326293468,
#   'conservative': 0.21469765156507492},
#  18: {'_id': '5d436e44a8a0d417d6e46ca6',
#   'year': 2016,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9982105556392084,
#   'personality_IND': {'extraversion': 0.45141090477927265,
#    'openness': 0.7010149265004095,
#    'agreeableness': 0.4618074768467953,
#    'conscientiousness': 0.44288770426278823},
#   'emotion_IND': {'surprise': 0.32010552287101746,
#    'fear': 0.2610233724117279,
#    'sadness': 0.1793673038482666,
#    'joy': 0.17444995045661926,
#    'anger': 0.06505381315946579},
#   'personas_IND': {'executive': 0.022058112546801567,
#    'entrepreneur': 0.027389084858732,
#    'consul': 0.017368725478810618,
#    'entertainer': 0.021566375173322695,
#    'commander': 0.07525791929358341,
#    'debater': 0.09344614976090942,
#    'protagonist': 0.05925866200424048,
#    'campaigner': 0.07358021396628624,
#    'logistician': 0.03451199171208333,
#    'virtuoso': 0.04285280242061611,
#    'defender': 0.027175006579458615,
#    'adventurer': 0.03374262480831437,
#    'architect': 0.11774810157800607,
#    'logician': 0.14620530088265765,
#    'advocate': 0.09271575694023945,
#    'mediator': 0.1151231736082875},
#   'liberal': 0.8319145478308201,
#   'conservative': 0.08699567429721355},
#  19: {'_id': '5d436e44a8a0d417d6e46ca7',
#   'year': 2015,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9845251844686977,
#   'personality_IND': {'extraversion': 0.5146253018055933,
#    'openness': 0.673836237637796,
#    'agreeableness': 0.6200890138483883,
#    'conscientiousness': 0.40761433250602636},
#   'emotion_IND': {'sadness': 0.3475022315979004,
#    'joy': 0.32318776845932007,
#    'fear': 0.14948657155036926,
#    'anger': 0.1064944863319397,
#    'surprise': 0.07332897186279297},
#   'personas_IND': {'executive': 0.018818732351064682,
#    'entrepreneur': 0.023833997695684252,
#    'consul': 0.03446233394973307,
#    'entertainer': 0.04364668022006432,
#    'commander': 0.05021292210057527,
#    'debater': 0.06359486148081346,
#    'protagonist': 0.0919538292241951,
#    'campaigner': 0.11645988298450505,
#    'logistician': 0.023663083191956667,
#    'virtuoso': 0.029969387059117378,
#    'defender': 0.04333368821660702,
#    'adventurer': 0.05488228496378046,
#    'architect': 0.0631388203110358,
#    'logician': 0.07996556192646458,
#    'advocate': 0.11562474473541166,
#    'mediator': 0.1464391897064815},
#   'liberal': 0.23817421356216073,
#   'conservative': 0.644915759563446},
#  20: {'_id': '5d436e44a8a0d417d6e46ca8',
#   'year': 2015,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9997067784319122,
#   'personality_IND': {'extraversion': 0.4975182439311076,
#    'openness': 0.7009377716300643,
#    'agreeableness': 0.5246761436002295,
#    'conscientiousness': 0.40710136140214986},
#   'emotion_IND': {'fear': 0.4551617503166199,
#    'joy': 0.2538643479347229,
#    'sadness': 0.19868701696395874,
#    'anger': 0.06749945878982544,
#    'surprise': 0.02478741481900215},
#   'personas_IND': {'executive': 0.020630797371268272,
#    'entrepreneur': 0.029511022690072088,
#    'consul': 0.022789769547307843,
#    'entertainer': 0.03259929121321376,
#    'commander': 0.06475991779749925,
#    'debater': 0.09263487350506579,
#    'protagonist': 0.07153691152610156,
#    'campaigner': 0.10232892467351773,
#    'logistician': 0.02660180108370408,
#    'virtuoso': 0.0380521557501268,
#    'defender': 0.02938562548072563,
#    'adventurer': 0.04203423648229792,
#    'architect': 0.08350284923283456,
#    'logician': 0.11944542456313793,
#    'advocate': 0.09224125262829405,
#    'mediator': 0.1319451453890017},
#   'liberal': 0.5955806239508092,
#   'conservative': 0.3255450651049614},
#  21: {'_id': '5d436e44a8a0d417d6e46ca9',
#   'year': 2015,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9999563122556617,
#   'personality_IND': {'extraversion': 0.4708719634908741,
#    'openness': 0.695943719594278,
#    'agreeableness': 0.4769588776847772,
#    'conscientiousness': 0.448476347429999},
#   'emotion_IND': {'joy': 0.5253840088844299,
#    'fear': 0.20039652287960052,
#    'sadness': 0.17861269414424896,
#    'anger': 0.05683063715696335,
#    'surprise': 0.03877614438533783},
#   'personas_IND': {'executive': 0.024054361507296562,
#    'entrepreneur': 0.027554666582426775,
#    'consul': 0.02009491079714807,
#    'entertainer': 0.023019049150679018,
#    'commander': 0.08286309705558931,
#    'debater': 0.09492103364652923,
#    'protagonist': 0.06922347248130287,
#    'campaigner': 0.07929662049825748,
#    'logistician': 0.03307819829154913,
#    'virtuoso': 0.03789161743366088,
#    'defender': 0.027633383623472473,
#    'adventurer': 0.03165449313258747,
#    'architect': 0.11394863964716401,
#    'logician': 0.1305300313681085,
#    'advocate': 0.09519220016125743,
#    'mediator': 0.10904422300716288},
#   'liberal': 0.352231714874506,
#   'conservative': 0.42655429244041443},
#  22: {'_id': '5d436e44a8a0d417d6e46caa',
#   'year': 2014,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9935139776345994,
#   'personality_IND': {'extraversion': 0.4892409309997397,
#    'openness': 0.6987733701679194,
#    'agreeableness': 0.5155465822470815,
#    'conscientiousness': 0.42444432535390747},
#   'emotion_IND': {'sadness': 0.4802761673927307,
#    'anger': 0.19031114876270294,
#    'fear': 0.173099547624588,
#    'joy': 0.11623987555503845,
#    'surprise': 0.040073294192552567},
#   'personas_IND': {'executive': 0.021725395694375038,
#    'entrepreneur': 0.02774042703738319,
#    'consul': 0.02250222850347902,
#    'entertainer': 0.028732338174375857,
#    'commander': 0.07151521204028703,
#    'debater': 0.09131536712623974,
#    'protagonist': 0.0740723729373258,
#    'campaigner': 0.09458051980427998,
#    'logistician': 0.028543477934500378,
#    'virtuoso': 0.03644620623064525,
#    'defender': 0.0295641036665261,
#    'adventurer': 0.03774940887466333,
#    'architect': 0.09395883355134169,
#    'logician': 0.1199728720046396,
#    'advocate': 0.09731850834267855,
#    'mediator': 0.1242627276625222},
#   'liberal': 0.23663457689690404,
#   'conservative': 0.7142162807285786},
#  23: {'_id': '5d436e44a8a0d417d6e46cab',
#   'year': 2014,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9999145376949939,
#   'personality_IND': {'extraversion': 0.4568836999646689,
#    'openness': 0.6942643487007818,
#    'agreeableness': 0.46035932710296223,
#    'conscientiousness': 0.46660542436714836},
#   'emotion_IND': {'sadness': 0.4076728820800781,
#    'joy': 0.19847477972507477,
#    'anger': 0.17964890599250793,
#    'fear': 0.1482054591178894,
#    'surprise': 0.06599795073270798},
#   'personas_IND': {'executive': 0.024821586906909943,
#    'entrepreneur': 0.025709014127744765,
#    'consul': 0.018747870295216514,
#    'entertainer': 0.019418147663974716,
#    'commander': 0.0896628266581916,
#    'debater': 0.09286846882348913,
#    'protagonist': 0.0677227838985541,
#    'campaigner': 0.07014402154750907,
#    'logistician': 0.03585283960559675,
#    'virtuoso': 0.03713465703952047,
#    'defender': 0.027079830061743016,
#    'adventurer': 0.028047993215977955,
#    'architect': 0.1295109295362932,
#    'logician': 0.13414122853602353,
#    'advocate': 0.09782025640261192,
#    'mediator': 0.10131754452336046},
#   'liberal': 0.8793374449014664,
#   'conservative': 0.0576061625033617},
#  24: {'_id': '5d436e45a8a0d417d6e46cac',
#   'year': 2013,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9853167192735784,
#   'personality_IND': {'extraversion': 0.44021109731520636,
#    'openness': 0.7137767664182966,
#    'agreeableness': 0.42810323625280144,
#    'conscientiousness': 0.46262925554966106},
#   'emotion_IND': {'joy': 0.45682597160339355,
#    'sadness': 0.24259310960769653,
#    'fear': 0.12798857688903809,
#    'anger': 0.11669748276472092,
#    'surprise': 0.0558948777616024},
#   'personas_IND': {'executive': 0.021762512624263763,
#    'entrepreneur': 0.024046711707498388,
#    'consul': 0.01392634372831055,
#    'entertainer': 0.015388055807130123,
#    'commander': 0.0902006999108903,
#    'debater': 0.09966818507066688,
#    'protagonist': 0.05772154716847037,
#    'campaigner': 0.06378001336392901,
#    'logistician': 0.03454498302854195,
#    'virtuoso': 0.03817083199080669,
#    'defender': 0.022106146285847724,
#    'adventurer': 0.024426412227330125,
#    'architect': 0.14318114691241288,
#    'logician': 0.15820947135881105,
#    'advocate': 0.09162497999799558,
#    'mediator': 0.10124195790673483},
#   'liberal': 0.960323000792414,
#   'conservative': 0.02548015397042036},
#  25: {'_id': '5d436e46a8a0d417d6e46cad',
#   'year': 2013,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.7416434322795692,
#   'personality_IND': {'extraversion': 0.509496275651253,
#    'openness': 0.69759163483281,
#    'agreeableness': 0.4512946621367805,
#    'conscientiousness': 0.4640002373991341},
#   'emotion_IND': {'anger': 0.4377523362636566,
#    'sadness': 0.3379986882209778,
#    'fear': 0.09841830283403397,
#    'joy': 0.09225182980298996,
#    'surprise': 0.03357882797718048},
#   'personas_IND': {'executive': 0.029945051297545433,
#    'entrepreneur': 0.03009192718964909,
#    'consul': 0.0208387037284353,
#    'entertainer': 0.020940913929887568,
#    'commander': 0.11651393590852689,
#    'debater': 0.11708541641021265,
#    'protagonist': 0.08108182264684492,
#    'campaigner': 0.08147951482265635,
#    'logistician': 0.030188317086388805,
#    'virtuoso': 0.030336385508067755,
#    'defender': 0.021007991472599134,
#    'adventurer': 0.021111032000863467,
#    'architect': 0.11746046221988711,
#    'logician': 0.1180365852677804,
#    'advocate': 0.0817405084762253,
#    'mediator': 0.0821414313909633},
#   'liberal': 0.4385388810187578,
#   'conservative': 0.3178211450576782},
#  26: {'_id': '5d436e46a8a0d417d6e46cae',
#   'year': 2013,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9995823703966843,
#   'personality_IND': {'extraversion': 0.4492046229415021,
#    'openness': 0.6896947580520238,
#    'agreeableness': 0.4831159486059557,
#    'conscientiousness': 0.4463124648592938},
#   'emotion_IND': {'surprise': 0.3286551833152771,
#    'joy': 0.3260789215564728,
#    'sadness': 0.17294567823410034,
#    'fear': 0.11125648766756058,
#    'anger': 0.061063751578330994},
#   'personas_IND': {'executive': 0.022304026409983635,
#    'entrepreneur': 0.026679127062272046,
#    'consul': 0.019670129799240123,
#    'entertainer': 0.023528570979037846,
#    'commander': 0.07035706199608391,
#    'debater': 0.08415811913530821,
#    'protagonist': 0.06204854915933105,
#    'campaigner': 0.07421983016594215,
#    'logistician': 0.035936290123153955,
#    'virtuoso': 0.042985458739504004,
#    'defender': 0.03169254941934062,
#    'adventurer': 0.037909276966155384,
#    'architect': 0.11335942808047153,
#    'logician': 0.1355957168029235,
#    'advocate': 0.09997273687062563,
#    'mediator': 0.1195831272816541},
#   'liberal': 0.4488117415457964,
#   'conservative': 0.4122450575232506},
#  27: {'_id': '5d436e46a8a0d417d6e46caf',
#   'year': 2013,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9969319845884562,
#   'personality_IND': {'extraversion': 0.5039148797928277,
#    'openness': 0.6939542157070658,
#    'agreeableness': 0.5143259099700995,
#    'conscientiousness': 0.4440163031391714},
#   'emotion_IND': {'fear': 0.5288639068603516,
#    'sadness': 0.21101917326450348,
#    'joy': 0.1342058777809143,
#    'anger': 0.07141312956809998,
#    'surprise': 0.054497942328453064},
#   'personas_IND': {'executive': 0.024790918454527855,
#    'entrepreneur': 0.02690120286827266,
#    'consul': 0.0246361306456051,
#    'entertainer': 0.02673323974406586,
#    'commander': 0.08703773700124505,
#    'debater': 0.09444667766649954,
#    'protagonist': 0.08649429921141073,
#    'campaigner': 0.09385698065073796,
#    'logistician': 0.0285346745182004,
#    'virtuoso': 0.030963640593049884,
#    'defender': 0.02835651248196099,
#    'adventurer': 0.030770312813757205,
#    'architect': 0.10018158740839975,
#    'logician': 0.10870937618637799,
#    'advocate': 0.09955608331880542,
#    'mediator': 0.10803062711540723},
#   'liberal': 0.5433217356912792,
#   'conservative': 0.2853212058544159},
#  28: {'_id': '5d436e46a8a0d417d6e46cb0',
#   'year': 2013,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9961752829315985,
#   'personality_IND': {'extraversion': 0.4845688401137368,
#    'openness': 0.6757369331110302,
#    'agreeableness': 0.5302751838115223,
#    'conscientiousness': 0.42073654374857056},
#   'emotion_IND': {'joy': 0.41435545682907104,
#    'sadness': 0.36255207657814026,
#    'fear': 0.11435045301914215,
#    'anger': 0.07497997581958771,
#    'surprise': 0.033762089908123016},
#   'personas_IND': {'executive': 0.022890865802764893,
#    'entrepreneur': 0.030837320158040245,
#    'consul': 0.026244757648336836,
#    'entertainer': 0.035355496793886096,
#    'commander': 0.06068774698228185,
#    'debater': 0.08175520127145121,
#    'protagonist': 0.06957950408348956,
#    'campaigner': 0.09373368832384299,
#    'logistician': 0.03147081768241571,
#    'virtuoso': 0.042395757986438624,
#    'defender': 0.0360818121668564,
#    'adventurer': 0.04860743663463526,
#    'architect': 0.08343471548814874,
#    'logician': 0.1123986685442675,
#    'advocate': 0.0956592791079778,
#    'mediator': 0.12886692958362642},
#   'liberal': 0.3674883274361491,
#   'conservative': 0.45077843964099884},
#  29: {'_id': '5d436e46a8a0d417d6e46cb1',
#   'year': 2013,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9999807573195559,
#   'personality_IND': {'extraversion': 0.49899424183166635,
#    'openness': 0.7149826589031754,
#    'agreeableness': 0.4995015274014389,
#    'conscientiousness': 0.42472627964513054},
#   'emotion_IND': {'sadness': 0.35072141885757446,
#    'joy': 0.2781467139720917,
#    'anger': 0.26402685046195984,
#    'fear': 0.07021565735340118,
#    'surprise': 0.03688935190439224},
#   'personas_IND': {'executive': 0.02125600539147854,
#    'entrepreneur': 0.026670676041661373,
#    'consul': 0.019906770467307225,
#    'entertainer': 0.024977742891524123,
#    'commander': 0.08211922668607526,
#    'debater': 0.10303795555307028,
#    'protagonist': 0.0769066718598185,
#    'campaigner': 0.09649757500907208,
#    'logistician': 0.02583591830322179,
#    'virtuoso': 0.03241725853041336,
#    'defender': 0.024195971775753215,
#    'adventurer': 0.030359558473730147,
#    'architect': 0.09981300052693737,
#    'logician': 0.12523897176027685,
#    'advocate': 0.09347732545283101,
#    'mediator': 0.11728937173323274},
#   'liberal': 0.7074589170515537,
#   'conservative': 0.20300454646348953},
#  30: {'_id': '5d436e46a8a0d417d6e46cb2',
#   'year': 2013,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9945778342832186,
#   'personality_IND': {'extraversion': 0.4434349468703998,
#    'openness': 0.6815904345467826,
#    'agreeableness': 0.41508374193258446,
#    'conscientiousness': 0.48519570097841064},
#   'emotion_IND': {'anger': 0.5815862417221069,
#    'sadness': 0.22478413581848145,
#    'fear': 0.10018114000558853,
#    'joy': 0.08381642401218414,
#    'surprise': 0.009632022120058537},
#   'personas_IND': {'executive': 0.02945868670940399,
#    'entrepreneur': 0.02923577746457579,
#    'consul': 0.017414630649226322,
#    'entertainer': 0.017282857585069766,
#    'commander': 0.09880858420905445,
#    'debater': 0.0980609192043547,
#    'protagonist': 0.05841112626940157,
#    'campaigner': 0.05796914083517724,
#    'logistician': 0.042985148792521806,
#    'virtuoso': 0.04265988867740889,
#    'defender': 0.025410858519303872,
#    'adventurer': 0.025218579581129198,
#    'architect': 0.14417824899091689,
#    'logician': 0.14308728071045532,
#    'advocate': 0.08523160183422546,
#    'mediator': 0.08458667116857471},
#   'liberal': 0.4754740900825709,
#   'conservative': 0.3615715056657791},
#  31: {'_id': '5d436e46a8a0d417d6e46cb3',
#   'year': 2013,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9962766884097471,
#   'personality_IND': {'extraversion': 0.4571007285582817,
#    'openness': 0.6778897203017616,
#    'agreeableness': 0.4632214025447243,
#    'conscientiousness': 0.4965350444632015},
#   'emotion_IND': {'joy': 0.4391933083534241,
#    'sadness': 0.24872365593910217,
#    'fear': 0.14501747488975525,
#    'anger': 0.11774596571922302,
#    'surprise': 0.04931962490081787},
#   'personas_IND': {'executive': 0.028763264417648315,
#    'entrepreneur': 0.024048212955775326,
#    'consul': 0.021347094213466523,
#    'entertainer': 0.017847745824801715,
#    'commander': 0.1030281096382296,
#    'debater': 0.08613910142734706,
#    'protagonist': 0.07646387351170401,
#    'campaigner': 0.06392944002447766,
#    'logistician': 0.039466165788330024,
#    'virtuoso': 0.032996626549071484,
#    'defender': 0.02929041326126638,
#    'adventurer': 0.024488946634277888,
#    'architect': 0.1413651843503417,
#    'logician': 0.11819172452846086,
#    'advocate': 0.10491631471332302,
#    'mediator': 0.08771778018841742},
#   'liberal': 0.6072536911815405,
#   'conservative': 0.25395409017801285},
#  32: {'_id': '5d436e46a8a0d417d6e46cb4',
#   'year': 2013,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9984484066667488,
#   'personality_IND': {'extraversion': 0.47819669948796095,
#    'openness': 0.6894356410637079,
#    'agreeableness': 0.5283743315621425,
#    'conscientiousness': 0.42653008713119334},
#   'emotion_IND': {'joy': 0.29698294401168823,
#    'sadness': 0.2335743010044098,
#    'fear': 0.23297876119613647,
#    'surprise': 0.1485205739736557,
#    'anger': 0.0879434272646904},
#   'personas_IND': {'executive': 0.02123246155679226,
#    'entrepreneur': 0.02691286382887287,
#    'consul': 0.023737002191618662,
#    'entertainer': 0.030087452104183395,
#    'commander': 0.06455603962911953,
#    'debater': 0.08182696090674495,
#    'protagonist': 0.07217094259188862,
#    'campaigner': 0.09147910764038837,
#    'logistician': 0.030302286889108663,
#    'virtuoso': 0.0384091722309063,
#    'defender': 0.03387668481587471,
#    'adventurer': 0.042939842344794525,
#    'architect': 0.09213230001929193,
#    'logician': 0.11678080246618,
#    'advocate': 0.10300004420580443,
#    'mediator': 0.13055603533057547},
#   'liberal': 0.4256485824007541,
#   'conservative': 0.519214540719986},
#  33: {'_id': '5d436e46a8a0d417d6e46cb5',
#   'year': 2013,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9986115280038304,
#   'personality_IND': {'extraversion': 0.512216319724665,
#    'openness': 0.664022694402766,
#    'agreeableness': 0.5452801203518581,
#    'conscientiousness': 0.47803585882159483},
#   'emotion_IND': {'surprise': 0.29199543595314026,
#    'joy': 0.27414390444755554,
#    'sadness': 0.25142568349838257,
#    'fear': 0.12013986706733704,
#    'anger': 0.06229511648416519},
#   'personas_IND': {'executive': 0.02981179766356945,
#    'entrepreneur': 0.024587636973180102,
#    'consul': 0.03350906457402804,
#    'entertainer': 0.027637003729122447,
#    'commander': 0.09564787600517272,
#    'debater': 0.07888673525928394,
#    'protagonist': 0.10751015678005217,
#    'campaigner': 0.08867029389270932,
#    'logistician': 0.031496478246037,
#    'virtuoso': 0.025977098967263468,
#    'defender': 0.035402681749752724,
#    'adventurer': 0.029198787252843847,
#    'architect': 0.10105299438515168,
#    'logician': 0.08334467160345775,
#    'advocate': 0.11358561970423514,
#    'mediator': 0.09368110495611129},
#   'liberal': 0.22798602283000946,
#   'conservative': 0.5274378508329391},
#  34: {'_id': '5d436e47a8a0d417d6e46cb6',
#   'year': 2012,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9982937479234069,
#   'personality_IND': {'extraversion': 0.5320533269037635,
#    'openness': 0.6643627099344662,
#    'agreeableness': 0.6546182721330408,
#    'conscientiousness': 0.3990614664280551},
#   'emotion_IND': {'sadness': 0.4261218309402466,
#    'joy': 0.2850353717803955,
#    'fear': 0.1485651284456253,
#    'anger': 0.08627396821975708,
#    'surprise': 0.05400366336107254},
#   'personas_IND': {'executive': 0.01791490614414215,
#    'entrepreneur': 0.0229946500240718,
#    'consul': 0.04029463729396836,
#    'entertainer': 0.05172012133111585,
#    'commander': 0.04416266989578726,
#    'debater': 0.056684928782273415,
#    'protagonist': 0.09933174207587596,
#    'campaigner': 0.12749710872728037,
#    'logistician': 0.020979744442058912,
#    'virtuoso': 0.02692851954772437,
#    'defender': 0.04718814710827027,
#    'adventurer': 0.0605682755257263,
#    'architect': 0.05171791344175549,
#    'logician': 0.06638245031678537,
#    'advocate': 0.1163251780479192,
#    'mediator': 0.14930900801041863},
#   'liberal': 0.5122813433408737,
#   'conservative': 0.3451605513691902},
#  35: {'_id': '5d436e47a8a0d417d6e46cb7',
#   'year': 2012,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9999900967121119,
#   'personality_IND': {'extraversion': 0.49489027185965395,
#    'openness': 0.6736202540798721,
#    'agreeableness': 0.5690262997359561,
#    'conscientiousness': 0.42364053479556374},
#   'emotion_IND': {'fear': 0.3940192759037018,
#    'joy': 0.31286680698394775,
#    'sadness': 0.20390379428863525,
#    'anger': 0.04783308506011963,
#    'surprise': 0.04137700796127319},
#   'personas_IND': {'executive': 0.02171582356095314,
#    'entrepreneur': 0.026725802836971402,
#    'consul': 0.030019372355691205,
#    'entertainer': 0.03694503189514245,
#    'commander': 0.05910413364690004,
#    'debater': 0.07273983202735104,
#    'protagonist': 0.08170396661382137,
#    'campaigner': 0.10055358975335182,
#    'logistician': 0.028843995204149715,
#    'virtuoso': 0.03549848778229429,
#    'defender': 0.03987316412162108,
#    'adventurer': 0.04907215589916425,
#    'architect': 0.07850493318932715,
#    'logician': 0.09661651903444456,
#    'advocate': 0.10852311072928617,
#    'mediator': 0.1335600804622897},
#   'liberal': 0.4875030256807804,
#   'conservative': 0.368087075650692},
#  36: {'_id': '5d436e47a8a0d417d6e46cb8',
#   'year': 2012,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.990897680150098,
#   'personality_IND': {'extraversion': 0.44673233971757403,
#    'openness': 0.6656276257795707,
#    'agreeableness': 0.5004021739750577,
#    'conscientiousness': 0.4669690690506464},
#   'emotion_IND': {'joy': 0.4985458552837372,
#    'sadness': 0.2687358856201172,
#    'surprise': 0.09750298410654068,
#    'fear': 0.0970030277967453,
#    'anger': 0.038212232291698456},
#   'personas_IND': {'executive': 0.025333214551210403,
#    'entrepreneur': 0.026191636364328145,
#    'consul': 0.024135369638611303,
#    'entertainer': 0.024953201565647783,
#    'commander': 0.0714268856523364,
#    'debater': 0.07384720025327018,
#    'protagonist': 0.06804956552148383,
#    'campaigner': 0.07035543894036023,
#    'logistician': 0.04058848332880948,
#    'virtuoso': 0.04196383237186637,
#    'defender': 0.03866931380916406,
#    'adventurer': 0.03997963140128139,
#    'architect': 0.1144390451465402,
#    'logician': 0.11831683555214821,
#    'advocate': 0.109027955367123,
#    'mediator': 0.11272238989097196},
#   'liberal': 0.7264013774693012,
#   'conservative': 0.1562507227063179},
#  37: {'_id': '5d436e47a8a0d417d6e46cb9',
#   'year': 2012,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9858263072680767,
#   'personality_IND': {'extraversion': 0.428738590266745,
#    'openness': 0.6819784942074356,
#    'agreeableness': 0.4084670512299788,
#    'conscientiousness': 0.49136733272294886},
#   'emotion_IND': {'joy': 0.3441203534603119,
#    'sadness': 0.3013579547405243,
#    'fear': 0.18333210051059723,
#    'anger': 0.08881289511919022,
#    'surprise': 0.08237671107053757},
#   'personas_IND': {'executive': 0.028372297063469887,
#    'entrepreneur': 0.027507553805889446,
#    'consul': 0.016191754366372636,
#    'entertainer': 0.0156982553588531,
#    'commander': 0.09646046772776241,
#    'debater': 0.09352050557101278,
#    'protagonist': 0.055048917294151234,
#    'campaigner': 0.05337111355312432,
#    'logistician': 0.045098540098665235,
#    'virtuoso': 0.043724008082203,
#    'defender': 0.02573723580716018,
#    'adventurer': 0.024952805655878475,
#    'architect': 0.15332654805672896,
#    'logician': 0.14865339791003834,
#    'advocate': 0.08750175757797322,
#    'mediator': 0.08483484270612794},
#   'liberal': 0.6967923305928707,
#   'conservative': 0.19497110694646835},
#  38: {'_id': '5d436e47a8a0d417d6e46cba',
#   'year': 2011,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.999840443039136,
#   'personality_IND': {'extraversion': 0.48846538667961703,
#    'openness': 0.6711492137374163,
#    'agreeableness': 0.47007695520133297,
#    'conscientiousness': 0.5103269077237995},
#   'emotion_IND': {'joy': 0.5224421620368958,
#    'surprise': 0.179554283618927,
#    'sadness': 0.14125119149684906,
#    'fear': 0.1058705747127533,
#    'anger': 0.050881773233413696},
#   'personas_IND': {'executive': 0.03362875431776047,
#    'entrepreneur': 0.024311519911511998,
#    'consul': 0.024906996939585986,
#    'entertainer': 0.018006224397871556,
#    'commander': 0.12574941202510181,
#    'debater': 0.09090907813240486,
#    'protagonist': 0.09313577016434141,
#    'campaigner': 0.06733142422249794,
#    'logistician': 0.03672735555246073,
#    'virtuoso': 0.026551615484681327,
#    'defender': 0.027201960553065743,
#    'adventurer': 0.019665341709745827,
#    'architect': 0.13733612903133435,
#    'logician': 0.09928556073104629,
#    'advocate': 0.10171742310945675,
#    'mediator': 0.07353543063118748},
#   'liberal': 0.47720006108283997,
#   'conservative': 0.3634292185306549},
#  39: {'_id': '5d436e47a8a0d417d6e46cbb',
#   'year': 2011,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9783856828198093,
#   'personality_IND': {'extraversion': 0.4305820939904553,
#    'openness': 0.6837396621704099,
#    'agreeableness': 0.415736014382881,
#    'conscientiousness': 0.48995903339879265},
#   'emotion_IND': {'sadness': 0.344111829996109,
#    'anger': 0.3320878744125366,
#    'fear': 0.22771263122558594,
#    'joy': 0.06471114605665207,
#    'surprise': 0.03137657791376114},
#   'personas_IND': {'executive': 0.02771833725273609,
#    'entrepreneur': 0.026744058705618322,
#    'consul': 0.016439681950730808,
#    'entertainer': 0.0158618392997297,
#    'commander': 0.09580894156092654,
#    'debater': 0.09244132818816814,
#    'protagonist': 0.05682406142031667,
#    'campaigner': 0.054826737725723794,
#    'logistician': 0.04396732998688687,
#    'virtuoso': 0.042421910884911256,
#    'defender': 0.02607692162086369,
#    'adventurer': 0.025160337129478308,
#    'architect': 0.15197388046495192,
#    'logician': 0.1466321110661291,
#    'advocate': 0.0901353566496991,
#    'mediator': 0.08696716558666717},
#   'liberal': 0.8562588635832071,
#   'conservative': 0.09219848737120628},
#  40: {'_id': '5d436e48a8a0d417d6e46cbc',
#   'year': 2011,
#   'tag': 'speech',
#   'decade': 2010,
#   'sentiment_IND': 0.9929550908726179,
#   'personality_IND': {'extraversion': 0.5122658327474432,
#    'openness': 0.6970427899717169,
#    'agreeableness': 0.46830530020228606,
#    'conscientiousness': 0.4391920806347639},
#   'emotion_IND': {'joy': 0.3219776749610901,
#    'sadness': 0.2564404010772705,
#    'fear': 0.21007254719734192,
#    'anger': 0.1667180061340332,
#    'surprise': 0.044791337102651596},
#   'personas_IND': {'executive': 0.027970781549811363,
#    'entrepreneur': 0.03330864535987216,
#    'consul': 0.022028072603845233,
#    'entertainer': 0.026231846645368706,
#    'commander': 0.09682112332431814,
#    'debater': 0.11529818812348094,
#    'protagonist': 0.07625037979285726,
#    'campaigner': 0.09080178304061873,
#    'logistician': 0.02926302725187667,
# ...
#    'logician': 0.10634667744246312,
#    'advocate': 0.09852798329521693,
#    'mediator': 0.08107222793967984},
#   'liberal': 0.24256511637941003,
#   'conservative': 0.4597158282995224},
#  191: {'_id': '5d436e5da8a0d417d6e46d53',
#   'year': 1984,
#   'tag': 'speech',
#   'decade': 1980,
#   'sentiment_IND': 0.9904133990833236,
#   'personality_IND': {'extraversion': 0.46267288039296356,
#    'openness': 0.6628713769333384,
#    'agreeableness': 0.4766242880570261,
#    'conscientiousness': 0.5132922542163695},
#   'emotion_IND': {'fear': 0.2839261293411255,
#    'joy': 0.271958589553833,
#    'sadness': 0.20576223731040955,
#    'surprise': 0.1644560992717743,
#    'anger': 0.07389696687459946},
#   'personas_IND': {'executive': 0.03196733817458153,
#    'entrepreneur': 0.023344231556319678,
#    'consul': 0.024979875816238707,
#    'entertainer': 0.018241618953644692,
#    'commander': 0.10918312042041918,
#    'debater': 0.07973125621322973,
#    'protagonist': 0.0853177314521629,
#    'campaigner': 0.06230349416421096,
#    'logistician': 0.04150919715908682,
#    'virtuoso': 0.030312198636133398,
#    'defender': 0.03243606266588746,
#    'adventurer': 0.023686518694501325,
#    'architect': 0.14177294403167703,
#    'logician': 0.10353005923596521,
#    'advocate': 0.11078402888195002,
#    'mediator': 0.08090032375983167},
#   'liberal': 0.40275560691952705,
#   'conservative': 0.41949135065078735},
#  192: {'_id': '5d436e5da8a0d417d6e46d54',
#   'year': 1984,
#   'tag': 'speech',
#   'decade': 1980,
#   'sentiment_IND': 0.9969761045251949,
#   'personality_IND': {'extraversion': 0.5215643482693172,
#    'openness': 0.640834278313913,
#    'agreeableness': 0.5342666292399689,
#    'conscientiousness': 0.4564374976459591},
#   'emotion_IND': {'sadness': 0.45218151807785034,
#    'joy': 0.25762540102005005,
#    'fear': 0.13695752620697021,
#    'anger': 0.12175078690052032,
#    'surprise': 0.03148479014635086},
#   'personas_IND': {'executive': 0.03425626456737518,
#    'entrepreneur': 0.035149930387432665,
#    'consul': 0.03811611880783752,
#    'entertainer': 0.039110477258539646,
#    'commander': 0.082184994566242,
#    'debater': 0.08432900467072953,
#    'protagonist': 0.09144525538307853,
#    'campaigner': 0.09383084356232622,
#    'logistician': 0.034473053536557136,
#    'virtuoso': 0.03537237312044231,
#    'defender': 0.038357332760351276,
#    'adventurer': 0.03935798390662712,
#    'architect': 0.08270509388371418,
#    'logician': 0.08486267213647357,
#    'advocate': 0.09202395731232758,
#    'mediator': 0.09442464244194128},
#   'liberal': 0.19745620992034674,
#   'conservative': 0.4726095050573349},
#  193: {'_id': '5d436e5da8a0d417d6e46d55',
#   'year': 1984,
#   'tag': 'speech',
#   'decade': 1980,
#   'sentiment_IND': 0.9995908036992065,
#   'personality_IND': {'extraversion': 0.5432136379561182,
#    'openness': 0.6302583746820967,
#    'agreeableness': 0.6522330673117386,
#    'conscientiousness': 0.4398205328261715},
#   'emotion_IND': {'sadness': 0.5233040452003479,
#    'surprise': 0.15524612367153168,
#    'joy': 0.14809279143810272,
#    'anger': 0.09577950835227966,
#    'fear': 0.07757753878831863},
#   'personas_IND': {'executive': 0.025005022063851357,
#    'entrepreneur': 0.024390875153593655,
#    'consul': 0.052916622110290294,
#    'entertainer': 0.051616938448165985,
#    'commander': 0.05595016264276811,
#    'debater': 0.05457597227724471,
#    'protagonist': 0.1184039557051783,
#    'campaigner': 0.11549583949095409,
#    'logistician': 0.025170059834849795,
#    'virtuoso': 0.02455185870564952,
#    'defender': 0.05326588000843739,
#    'adventurer': 0.0519576182329342,
#    'architect': 0.05631944237806326,
#    'logician': 0.054936182143383874,
#    'advocate': 0.11918544014338947,
#    'mediator': 0.11625812991193507},
#   'liberal': 0.6624902412295341,
#   'conservative': 0.23283642530441284},
#  194: {'_id': '5d436e5da8a0d417d6e46d56',
#   'year': 1984,
#   'tag': 'speech',
#   'decade': 1980,
#   'sentiment_IND': 0.9990161834289165,
#   'personality_IND': {'extraversion': 0.4955447616718583,
#    'openness': 0.6037452658203161,
#    'agreeableness': 0.5526217039217027,
#    'conscientiousness': 0.48881820015523625},
#   'emotion_IND': {'sadness': 0.39125800132751465,
#    'joy': 0.3469596803188324,
#    'fear': 0.13878771662712097,
#    'anger': 0.0692685917019844,
#    'surprise': 0.05372597277164459},
#   'personas_IND': {'executive': 0.03764016553759575,
#    'entrepreneur': 0.031891970040171906,
#    'consul': 0.045919077376407935,
#    'entertainer': 0.03890657341972582,
#    'commander': 0.07593824956858093,
#    'debater': 0.06434138599926233,
#    'protagonist': 0.0926407831966448,
#    'campaigner': 0.0784932023689348,
#    'logistician': 0.04317236320619231,
#    'virtuoso': 0.03657932203245382,
#    'defender': 0.05266807653051894,
#    'adventurer': 0.044624903275238006,
#    'architect': 0.08709934450744257,
#    'logician': 0.07379802111681484,
#    'advocate': 0.10625674856775144,
#    'mediator': 0.09002981387462627},
#   'liberal': 0.24679530691355467,
#   'conservative': 0.5586845576763153},
#  195: {'_id': '5d436e5da8a0d417d6e46d57',
#   'year': 1984,
#   'tag': 'speech',
#   'decade': 1980,
#   'sentiment_IND': 0.9911802841919315,
#   'personality_IND': {'extraversion': 0.48466375950029345,
#    'openness': 0.6609366859231038,
#    'agreeableness': 0.5420329968134562,
#    'conscientiousness': 0.5049498807424786},
#   'emotion_IND': {'sadness': 0.699176013469696,
#    'anger': 0.1262442171573639,
#    'fear': 0.09810759127140045,
#    'joy': 0.06111420691013336,
#    'surprise': 0.015357968397438526},
#   'personas_IND': {'executive': 0.028872165828943253,
#    'entrepreneur': 0.01996530230858138,
#    'consul': 0.031321797525765846,
#    'entertainer': 0.021659238281557008,
#    'commander': 0.0992136750494905,
#    'debater': 0.06860693824861636,
#    'protagonist': 0.10763135941909861,
#    'campaigner': 0.0744278248497222,
#    'logistician': 0.0350469734749524,
#    'virtuoso': 0.024235223055667898,
#    'defender': 0.03802049865356327,
#    'adventurer': 0.026291436155403382,
#    'architect': 0.12043221323843818,
#    'logician': 0.08327970325332847,
#    'advocate': 0.13065016311751307,
#    'mediator': 0.09034548582847708},
#   'liberal': 0.07557461853139102,
#   'conservative': 0.6600975692272186},
#  196: {'_id': '5d436e5da8a0d417d6e46d58',
#   'year': 1984,
#   'tag': 'speech',
#   'decade': 1980,
#   'sentiment_IND': 0.9975135672047587,
#   'personality_IND': {'extraversion': 0.478167768252098,
#    'openness': 0.6641458189376045,
#    'agreeableness': 0.5085008489458185,
#    'conscientiousness': 0.5178438908067242},
#   'emotion_IND': {'sadness': 0.4281904399394989,
#    'fear': 0.24095244705677032,
#    'anger': 0.1549866795539856,
#    'joy': 0.12467806041240692,
#    'surprise': 0.05119238421320915},
#   'personas_IND': {'executive': 0.030874809250235558,
#    'entrepreneur': 0.020259311502231227,
#    'consul': 0.027819864310821545,
#    'entertainer': 0.01825472934867772,
#    'commander': 0.11340417063740497,
#    'debater': 0.07441310348849643,
#    'protagonist': 0.10218325740087951,
#    'campaigner': 0.06705020869184246,
#    'logistician': 0.0370925367443754,
#    'virtuoso': 0.024339235143611682,
#    'defender': 0.033422370698524634,
#    'adventurer': 0.021930959995926973,
#    'architect': 0.13624208182524247,
#    'logician': 0.08939879439500975,
#    'advocate': 0.12276144376112169,
#    'mediator': 0.0805531222321774},
#   'liberal': 0.34636981040239334,
#   'conservative': 0.3970123678445816},
#  197: {'_id': '5d436e5da8a0d417d6e46d59',
#   'year': 1983,
#   'tag': 'speech',
#   'decade': 1980,
#   'sentiment_IND': 0.9998293418240576,
#   'personality_IND': {'extraversion': 0.5065308016235546,
#    'openness': 0.642538965862488,
#    'agreeableness': 0.512662947177887,
#    'conscientiousness': 0.47635134643521804},
#   'emotion_IND': {'sadness': 0.46657752990722656,
#    'joy': 0.2520820200443268,
#    'anger': 0.1401597559452057,
#    'fear': 0.12800797820091248,
#    'surprise': 0.013172725215554237},
#   'personas_IND': {'executive': 0.0358683317899704,
#    'entrepreneur': 0.032905728062399664,
#    'consul': 0.03506752051749547,
#    'entertainer': 0.03217106064589101,
#    'commander': 0.09241393280898509,
#    'debater': 0.0847808511422949,
#    'protagonist': 0.0903506596567414,
#    'campaigner': 0.08288799744946669,
#    'logistician': 0.03786714134872059,
#    'virtuoso': 0.034739442162967704,
#    'defender': 0.03702170328843888,
#    'adventurer': 0.03396383445793769,
#    'architect': 0.09756381830489123,
#    'logician': 0.08950537332587881,
#    'advocate': 0.09538556659738144,
#    'mediator': 0.08750703792177315},
#   'liberal': 0.056983909220434725,
#   'conservative': 0.7078330665826797},
#  198: {'_id': '5d436e5ea8a0d417d6e46d5a',
#   'year': 1983,
#   'tag': 'speech',
#   'decade': 1980,
#   'sentiment_IND': 0.9842374440804813,
#   'personality_IND': {'extraversion': 0.5168981009115607,
#    'openness': 0.631459371508839,
#    'agreeableness': 0.5311591865723592,
#    'conscientiousness': 0.4548725355630633},
#   'emotion_IND': {'sadness': 0.6620197892189026,
#    'surprise': 0.10050006955862045,
#    'anger': 0.08486422896385193,
#    'joy': 0.07886628061532974,
#    'fear': 0.0737496018409729},
#   'personas_IND': {'executive': 0.03522535040974617,
#    'entrepreneur': 0.037566552443012685,
#    'consul': 0.03910142005972611,
#    'entertainer': 0.04170024100343865,
#    'commander': 0.07752825291725539,
#    'debater': 0.08268105931413429,
#    'protagonist': 0.08605918352846928,
#    'campaigner': 0.09177898624179695,
#    'logistician': 0.03642316253305532,
#    'virtuoso': 0.038843976853419226,
#    'defender': 0.04043103657275657,
#    'adventurer': 0.04311822860979235,
#    'architect': 0.08016454707607949,
#    'logician': 0.0854925710600249,
#    'advocate': 0.08898556603177965,
#    'mediator': 0.09489986664639327},
#   'liberal': 0.801081130746752,
#   'conservative': 0.14475879818201065},
#  199: {'_id': '5d436e5fa8a0d417d6e46d5b',
#   'year': 1983,
#   'tag': 'speech',
#   'decade': 1980,
#   'sentiment_IND': 0.9965217379343227,
#   'personality_IND': {'extraversion': 0.46263609851820997,
#    'openness': 0.6594451184027662,
#    'agreeableness': 0.4693498365711747,
#    'conscientiousness': 0.4892420340543505},
#   'emotion_IND': {'sadness': 0.5712122917175293,
#    'anger': 0.1399177610874176,
#    'joy': 0.1095823124051094,
#    'surprise': 0.1006244570016861,
#    'fear': 0.07866315543651581},
#   'personas_IND': {'executive': 0.03200358897447586,
#    'entrepreneur': 0.028840311312814008,
#    'consul': 0.025069584147907595,
#    'entertainer': 0.022591673812064637,
#    'commander': 0.09422884450369357,
#    'debater': 0.08491514283426521,
#    'protagonist': 0.07381291053433828,
#    'campaigner': 0.06651714635841141,
#    'logistician': 0.04277478365031246,
#    'virtuoso': 0.03854686834484849,
#    'defender': 0.0335070571578794,
#    'adventurer': 0.030195176004792143,
#    'architect': 0.12594270651153633,
#    'logician': 0.11349436543225205,
#    'advocate': 0.09865554201743462,
#    'mediator': 0.08890429980252959},
#   'liberal': 0.1732678860425949,
#   'conservative': 0.6431450098752975},
#  200: {'_id': ObjectId('5d436e5fa8a0d417d6e46d5c'),
#   'year': 1983,
#   'text': 'My fellow Americans: I\'m coming before you tonight about the Korean airline massacre, the attack by the Soviet Union against 269 innocent men, women, and children aboard an unarmed Korean passenger plane. This crime against humanity must never be forgotten, here or throughout the world. Our prayers tonight are with the victims and their families in their time of terrible grief. Our hearts go out to them—to brave people like Kathryn McDonald, the wife of a Congressman whose composure and eloquence on the day of her husband\'s death moved us all. He will be sorely missed by all of us here in government. The parents of one slain couple wired me: "Our daughter ... and her husband ... died on Korean Airline Flight 007. Their deaths were the result of the Soviet Union violating every concept of human rights." The emotions of these parents—grief, shock, anger—are shared by civilized people everywhere. From around the world press accounts reflect an explosion of condemnation by people everywhere. Let me state as plainly as I can: There was absolutely no justification, either legal or moral, for what the Soviets did. One newspaper in India said, "If every passenger plane ... is fair game for home air forces . . . it will be the end to civil aviation as we know it." This is not the first time the Soviet Union has shot at and hit a civilian airliner when it overflew its territory. In another tragic incident in 1978, the Soviets also shot down an unarmed civilian airliner after having positively identified it as such. In that instance, the Soviet interceptor pilot clearly identified the civilian markings on the side of the aircraft, repeatedly questioned the order to fire on a civilian airliner, and was ordered to shoot it down anyway. The aircraft was hit with a missile and made a crash landing. Several innocent people lost their lives in this attack, killed by shrapnel from the blast of a Soviet missile. Is this a practice of other countries in the world? The answer is no. Commercial aircraft from the Soviet Union and Cuba on a number of occasions have overflown sensitive United States military facilities. They weren\'t shot down. We and other civilized countries believe in the tradition of offering help to mariners and pilots who are lost or in distress on the sea or in the air. We believe in following procedures to prevent a tragedy, not to provoke one. But despite the savagery of their crime, the universal reaction against it, and the evidence of their complicity, the Soviets still refuse to tell the truth. They have persistently refused to admit that their pilot fired on the Korean aircraft. Indeed, they\'ve not even told their own people that a plane was shot down. They have spun a confused tale of tracking the plane by radar until it just mysteriously disappeared from their radar screens, but no one fired a shot of any kind. But then they coupled this with charges that it was a spy plane sent by us and that their planes fired tracer bullets past the plane as a warning that it was in Soviet airspace. Let me recap for a moment and present the incontrovertible evidence that we have. The Korean airliner, a Boeing 747, left Anchorage, Alaska, bound for Seoul, Korea, on a course south and west which would take it across Japan. Out over the Pacific, in international waters, it was for a brief time in the vicinity of one of our reconnaissance planes, an RC-135, on a routine mission. At no time was the RC-135 in Soviet airspace. The Korean airliner flew on, and the two planes were soon widely separated. The 747 is equipped with the most modern computerized navigation facilities, but a computer must respond to input provided by human hands. No one will ever know whether a mistake was made in giving the computer the course or whether there was a malfunction. Whichever, the 747 was flying a course further to the west than it was supposed to fly—a course which took it into Soviet airspace. The Soviets tracked this plane for 2 1/2 h ...
#   'tag': 'speech',
#   'decade': 1980,
#   'sentiment_IND': 0.9931328173596603,
#   'personality_IND': {'extraversion': 0.46011393201553213,
#    'openness': 0.6387942514129887,
#    'agreeableness': 0.42887608053391435,
#    'conscientiousness': 0.5260942879764513},
#   'emotion_IND': {'anger': 0.39648354053497314,
#    'sadness': 0.34642523527145386,
#    'fear': 0.1294991672039032,
#    'joy': 0.07858262956142426,
#    'surprise': 0.04900946095585823},
#   'personas_IND': {'executive': 0.04195542261004448,
#    'entrepreneur': 0.031099248023706262,
#    'consul': 0.02565412721534654,
#    'entertainer': 0.019015993623378222,
#    'commander': 0.11848336944997864,
#    'debater': 0.08782520562965584,
#    'protagonist': 0.07244802177273511,
#    'campaigner': 0.053701734169017516,
#    'logistician': 0.05124092550851889,
#    'virtuoso': 0.037982080019588436,
#    'defender': 0.031331854454591086,
#    'adventurer': 0.023224580571998634,
#    'architect': 0.14470590465753747,
#    'logician': 0.10726252883734048,
#    'advocate': 0.08848209314049428,
#    'mediator': 0.06558690945978725},
#   'liberal': 0.29351210594177246,
#   'conservative': 0.44676265120506287}}
